# %% [markdown]
# ## Задача - вычленить из резюме данные в кратком формате, чтобы рекрутер мог увидеть основную информацию о соискателе без прочтения резюме полностью

# %% [markdown]
# spaCy имеет предобученные модели для задачи NER, а также инструменты для работы с текстом. Основная идея здесь - добавить в пайплайн обработки текста собственные правила на основе регулярных выражений, которые будут искать такую информацию, как email, ФИО, данные об образовании. После чего в пайплане будет использована обученная на собственных данных (данные парсились с superjob, были размечены для NER, анонимизированы (ФИО, контактные данные генерировались при помощи python библиотек)) модель, которая будет размечать в тексте более сложную информацию, например, об опыте работы кандидата (например, с какого по какой года где работал кандидат, какую должность занимал, какие задачи выполнял). Небольшое заключение о возможных способах применения полученных результатов приведено в конце нотбука.

# %%
import re
import spacy

# %%
import pandas as pd

# %%
import random
import warnings
warnings.filterwarnings('ignore')
from spacy.util import minibatch, compounding

# %%
nlp = spacy.load("en_core_web_lg")

# %%
skills = "D:\Python\Diplom\jz_skill_patterns.jsonl"

# %%
ruler = nlp.add_pipe("entity_ruler", before="ner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-5ed98dfd8ac5> in <module>
# ----> 1 ruler = nlp.add_pipe("entity_ruler", before="ner")
#
# D:\Anaconda\lib\site-packages\spacy\language.py in add_pipe(self, factory_name, name, before, after, first, last, source, config, raw_config, validate)
#     750         name = name if name is not None else factory_name
#     751         if name in self.component_names:
# --> 752             raise ValueError(Errors.E007.format(name=name, opts=self.component_names))
#     753         if source is not None:
#     754             # We're loading the component from a model. After loading the
#
# ValueError: [E007] 'entity_ruler' already exists in pipeline. Existing names: ['tok2vec', 'morphologizer', 'parser', 'senter', 'entity_ruler', 'ner', 'attribute_ruler', 'lemmatizer']

# %%
ruler.from_disk(skills)

# %%
patterns = [
    {"label":"EMAIL", "pattern":[{"TEXT": {"REGEX":"([^@|\s]+@[^@]+\.[^@|\s]+)"}}]},
    {"label":"MOBILE", "pattern":[{"TEXT": {"REGEX":"\d{3}[-\.\s]??\d{3}[-\.\s]??\d{4}|\(\d{3}\)\s*\d{3}[-\.\s]??\d{4}|\d{3}[-\.\s]??\d{4}"}}]},
]

# %%
ruler.add_patterns(patterns)

# %%
import docx

# %%
doco = docx.Document("D:\\Python\\Diplom\\Resume.docx")
text = ""
all_paras = doco.paragraphs
for para in all_paras:
    text += str(para.text)
tx = " ".join(text.split("\n"))

# %%
doc = nlp(tx)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">MARIA LISAEmail:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     maria123@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EMAIL</span>
# </mark>
#  Phone: (555)-555-5555CAREER SUMMARYAround 3 Years of experience in Analysis,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Design
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Development, Management and Validation of various stand-alone and client-
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     server
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  applications.2+ years of experience in implementing Object-Oriented
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# , Hash Tables (Dictionaries) and Multi threading.Experience in installing
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     software
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  using pip command for
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     libraries
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and extensive usage of the PEP8 coding convention.Good understanding on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Django
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  ORM and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SQLAlchemy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# .Experienced in interfacing with third party
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     API
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ’s using REST and SOAPWorked with varieties of Relational
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Databases
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  (RDBMS) like
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SQLite
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MySQL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and PostgreSQL.Experienced in writing SubQueries, Triggers, Cursors, Stored Procedures and Functions.Proficient knowledge of Web services like
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Google
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Cloud and Amazon AWS Services.Good Knowledge on
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Linux
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Shell
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  Scripting.Experienced in developing web-based applications using
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PHP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     XML
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     JSON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and MVC3Well versed in
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     design
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
#  and development of presentation layer for web applications using technologies like
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     HTML
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CSS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; bor

# %%
from spacy import displacy

# %%
dic = {}
skillls = []
i = 0
for ent in doc.ents:
    if ent.label_ == "PERSON" and i == 0: 
        dic["PERSON"] = ent.text
        i = i + 1
    if ent.label_ == "EMAIL":
        dic["EMAIL"] = ent.text
    if ent.label_ == "MOBILE":
        dic["MOBILE"] = ent.text 
    if ent.label_ == "SKILL":
        skillls.append(ent.text)

skillls = [i.capitalize() for i in set([i.lower() for i in skillls])]
dic["SKILLS"] = skillls

# %%
dic
# Out:
# {'EMAIL': 'maria123@gmail.com',
#  'SKILLS': ['Api',
#   'Deployment',
#   'Pycharm',
#   'Queue',
#   'Xml',
#   'Algorithms',
#   'Data exchange',
#   'Data management',
#   'Windows',
#   'Javascript',
#   'Tensorflow',
#   'Eclipse',
#   'Front end',
#   'Django',
#   'Pytorch',
#   'Databases',
#   'Support',
#   'Oracle',
#   'Java',
#   'Html5',
#   'Rabbitmq',
#   'Shell',
#   'Visual studio',
#   'Database',
#   'C++',
#   'Software',
#   'Sql',
#   'Sqlalchemy',
#   'Bootstrap',
#   'Json',
#   'Design',
#   'Testing',
#   'Ajax',
#   'Business',
#   'Html',
#   'Debugging',
#   'Server',
#   'Monitoring',
#   'Google',
#   'Mysql',
#   'Linux',
#   'Libraries',
#   'Numpy',
#   'Python',
#   'Sqlite',
#   'Pandas',
#   'Languages',
#   'Css',
#   'Angular 2',
#   'Code coverage',
#   'Php',
#   'Framework',
#   'Jquery']}

# %%
nlp = spacy.load("ru_core_news_lg")

# %%
ruler = nlp.add_pipe("entity_ruler", before="ner")

# %%
ruler.from_disk(skills)

# %%
ruler.add_patterns(patterns)

# %%
doco = docx.Document("D:\\Python\\Diplom\\К.docx")
text = ""
all_paras = doco.paragraphs
for para in all_paras:
    text += str(para.text)
tx = " ".join(text.split("\n"))

# %%
doc = nlp(tx)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Артур Валериевич Гаврюшев
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# . Контакты:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     culch1945@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EMAIL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +7(986)1177845Соискатель
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOBILE</span>
# </mark>
#  скрыл дату рождения,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     высшее образование
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EDUCATION</span>
# </mark>
# , cостоит в браке, есть детиРостов-на-Дону,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     готов к переезду: Москва, Санкт-ПетербургГражданство: РоссияТехнический писательПолная занятость, удаленная работа, готов к командировкамПо договорённостиОпыт работы 41 год и 8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKCONDITIONS</span>
# </mark>
#  месяцевМай 2021 –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ноябрь 20217
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
#  месяцевТехнический писатель (удаленно)ООО &quot;Квант&quot;, ЗеленоградРазработка технологического оборудования для производства микрочипов.Обязанности:Оформление пояснительных записок: технического предложения, эскизного проекта, технического проекта разрабатываемого комплекса технологического оборудования для производства микрочипов. Выполнение расчетов планируемых показателей надежности компонентов комплекса.Достижения:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Пояснительные записки, оформленные в соответствии с ГОСТ 2.105-2019 приняты заказчиком без замечаний.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SPEC</span>
# </mark>
#  Приобрел опыт создания шаблонов в Microsoft Word.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ноябрь 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKFROM</span>
# </mark>
#  –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     январь 20215
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
#  лет и 3 месяцаВедущий инженер-метролог / технический писательАО &quot;НПЦ &quot;Мера&quot;, МытищиРазработка и производство измерительных систем для стендовых испытаний двигателей для авиационной и ракетной техники и других изделий военного и гражданского назначений.Обязанности:- Разработка технической документации: ТУ, РЭ, ТЗ, описаний типа, методик поверки, программ испытаний с целью утверждения типа, протоколов испытаний, актов испытаний и д-р на автоматизированные информационно-измерительные системы стендов испытания авиационных, ракетных двигателей и других объектов, разработанных в том числе и по: ГОСТ 2., ГОСТ РВ, КТ-160D, ОСТ 1., РК-11;- проведение метрологической экспертизы технических заданий на разработку;- организация испытаний на ВВФ и калибровки первичных преобразователей, написание программ и методик испытаний.- участие в переговорах с заказчиками с целью уточнения требований к системе измерений;- участие в испытаниях систем с целью присвоения типа средств измерения.Примеры работ на сайте Росстандарта  под номерами: 66375-16, 66432-17, 67371-17, 70281-18, 71139-18, 73004-18, 74251-19, 76889-19, 77013-19, 78335-20, 78520-20, 79465-20. Вся разработанная документация прошла проверку в отделе экспертиз ВНИИМС, в Росстандарте и Военной Приемке без возвратов на доработку. Вся разработанная документация прошла проверку в отделе экспертиз ВНИИМС, в Росстандарте и Военной Приемке без возвратов на доработку.Достижения:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Вся разработанная документация прошла проверку в отделе экспертиз ВНИИМСа, в Росстандарте и Военной Приемке без возвратов на доработку.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SPEC</span>
# </mark>
#  Приобрел опыт работы в программе Microsoft Visio.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Апрель 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKFROM</span>
# </mark>
#  –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     сентябрь 20156
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
#  месяцевТехнический писательЗАО Научно-Исследовательский Центр &quot;ТЕХНОПРОГРЕСС&quot;, МоскваИспытательная лабораторияОбязанности:- оформление протоколов испытаний, проводимых лабораторией;- создание автоматизированной системы заполнения протоколов.Достижения:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Приобрел опыт создания базы данных в программе FileMaker, создания автоматизированной системы заполнения протоколов с использованием Microsoft Word
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SPEC</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ноябрь 2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKFROM</span>
# </mark>
#  –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     сентябрь 20123
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
#  года и 11 месяцевТехнический директорООО &quot;Дижитал Иновэйшинс&quot;, Ростов-на-ДонуОбязанности:- управление инфраструктурой, производственной средой и производством компании, занимающейся производством радиоэлектронной аппаратуры;- планирование и контроль технической политики компании;- разработка и внедрение регламентирующих документов (стандарты, должностные инструкции, карты процессов и т. д.);- управл

# %%
dic = {}
skillls = []
i = 0
for ent in doc.ents:
    if ent.label_ == "PERSON" and i == 0: 
        dic["PERSON"] = ent.text
        i = i + 1
    if ent.label_ == "EMAIL":
        dic["EMAIL"] = ent.text
    if ent.label_ == "MOBILE":
        dic["MOBILE"] = ent.text 
    if ent.label_ == "SKILL":
        skillls.append(ent.text)

skillls = [i.capitalize() for i in set([i.lower() for i in skillls])]
dic["SKILLS"] = skillls

# %%
dic
# Out:
# {'EMAIL': 'culch1945@gmail.com',
#  'MOBILE': '+7(986)1177845Соискатель',
#  'SKILLS': ['Adobe photoshop']}

# %%
test = pd.read_json("my_cleaned_res.json")
train_data = []
for i in range(160):
    train_data.append([test[0][i],test[1][i]])
train_data
# Out:
# [['Артур Валериевич Гаврюшев. Контакты: culch1945@gmail.com, +7(986)1177845\r\nСоискатель скрыл дату рождения, высшее образование, cостоит в браке, есть дети\r\nРостов-на-Дону, готов\xa0к\xa0переезду: Москва, Санкт-Петербург\r\nГражданство: Россия\r\nТехнический писатель\r\nПолная занятость, удаленная работа, готов к\xa0командировкам\r\nПо договорённости\r\nОпыт работы 41 год\xa0и\xa08 месяцев\r\nМай\xa02021 – ноябрь\xa02021\r\n7 месяцев\r\nТехнический писатель (удаленно)\r\nООО "Квант", Зеленоград\r\nhttp://tvkvant.ru\r\nРазработка технологического оборудования для производства микрочипов.\r\nОбязанности:\r\nОформление пояснительных записок: технического предложения, эскизного проекта, технического проекта разрабатываемого комплекса технологического оборудования для производства микрочипов. Выполнение расчетов планируемых показателей надежности компонентов комплекса.\r\nДостижения:\r\nПояснительные записки, оформленные в соответствии с ГОСТ 2.105-2019 приняты заказчиком без замечаний. Приобрел опыт создания шаблонов в Microsoft Word.\r\nНоябрь\xa02015 – январь\xa02021\r\n5 лет\xa0и\xa03 месяца\r\nВедущий инженер-метролог / технический писатель\r\nАО "НПЦ "Мера", Мытищи\r\nhttp://nppmera.ru\r\nРазработка и производство измерительных систем для стендовых испытаний двигателей для авиационной и ракетной техники и других изделий военного и гражданского назначений.\r\nОбязанности:\r\n- Разработка технической документации: ТУ, РЭ, ТЗ, описаний типа, методик поверки, программ испытаний с целью утверждения типа, протоколов испытаний, актов испытаний и д-р на автоматизированные информационно-измерительные системы стендов испытания авиационных, ракетных двигателей и других объектов, разработанных в том числе и по: ГОСТ 2., ГОСТ РВ, КТ-160D, ОСТ 1., РК-11;\r\n- проведение метрологической экспертизы технических заданий на разработку;\r\n- организация испытаний на ВВФ и калибровки первичных преобразователей, написание программ и методик испытаний.\r\n- участие в переговорах с заказчиками с целью уточнения требований к системе измерений;\r\n- участие в испытаниях систем с целью присвоения типа средств измерения.\r\nПримеры работ на сайте Росстандарта https://fgis.gost.ru/fundmetrology/registry/4 под номерами: 66375-16, 66432-17, 67371-17, 70281-18, 71139-18, 73004-18, 74251-19, 76889-19, 77013-19, 78335-20, 78520-20, 79465-20. Вся разработанная документация прошла проверку в отделе экспертиз ВНИИМС, в Росстандарте и Военной Приемке без возвратов на доработку. Вся разработанная документация прошла проверку в отделе экспертиз ВНИИМС, в Росстандарте и Военной Приемке без возвратов на доработку.\r\nДостижения:\r\nВся разработанная документация прошла проверку в отделе экспертиз ВНИИМСа, в Росстандарте и Военной Приемке без возвратов на доработку. Приобрел опыт работы в программе Microsoft Visio.\r\nАпрель\xa02015 – сентябрь\xa02015\r\n6 месяцев\r\nТехнический писатель\r\nЗАО Научно-Исследовательский Центр "ТЕХНОПРОГРЕСС", Москва\r\nhttp://www.tehnoprogress.ru\r\nИспытательная лаборатория\r\nОбязанности:\r\n- оформление протоколов испытаний, проводимых лабораторией;\r\n- создание автоматизированной системы заполнения протоколов.\r\nДостижения:\r\nПриобрел опыт создания базы данных в программе FileMaker, создания автоматизированной системы заполнения протоколов с использованием Microsoft Word.\r\nНоябрь\xa02008 – сентябрь\xa02012\r\n3 года\xa0и\xa011 месяцев\r\nТехнический директор\r\nООО "Дижитал Иновэйшинс", Ростов-на-Дону\r\nОбязанности:\r\n- управление инфраструктурой, производственной средой и производством компании, занимающейся производством радиоэлектронной аппаратуры;\r\n- планирование и контроль технической политики компании;\r\n- разработка и внедрение регламентирующих документов (стандарты, должностные инструкции, карты процессов и т. д.);\r\n- управление технологической подготовкой производства и разработкой технической документации новых моделей изделий;\r\n- оценка инновационных технологий в отрасли с позиций перспективности их при ...
#   {'entities': [[0, 25, 'NAME'],
#     [58, 72, 'PHONE'],
#     [154, 168, 'CITY'],
#     [37, 56, 'EMAIL'],
#     [346, 364, 'WOEXP'],
#     [74, 104, 'AGE'],
#     [106, 124, 'EDUCATION'],
#     [256, 313, 'WORKCONDITIONS'],
#     [315, 332, 'SALARY'],
#     [234, 254, 'VACANCY'],
#     [170, 211, 'WORKCONDITIONS'],
#     [366, 374, 'WORKFROM'],
#     [377, 388, 'WORKTO'],
#     [401, 432, 'POSITION'],
#     [434, 457, 'ORG'],
#     [563, 826, 'SUMMARY'],
#     [994, 1005, 'WORKFROM'],
#     [1008, 1019, 'WORKTO'],
#     [1039, 1086, 'POSITION'],
#     [1088, 1110, 'ORG'],
#     [1316, 2528, 'SUMMARY'],
#     [2730, 2741, 'WORKFROM'],
#     [2744, 2757, 'WORKTO'],
#     [2770, 2790, 'POSITION'],
#     [2792, 2850, 'ORG'],
#     [2922, 3043, 'SUMMARY'],
#     [3208, 3219, 'WORKFROM'],
#     [3222, 3235, 'WORKTO'],
#     [3258, 3278, 'POSITION'],
#     [3280, 3320, 'ORG'],
#     [3336, 4044, 'SUMMARY'],
#     [4363, 4371, 'WORKFROM'],
#     [4374, 4387, 'WORKTO'],
#     [4409, 4435, 'POSITION'],
#     [4437, 4468, 'ORG'],
#     [4500, 4832, 'SUMMARY'],
#     [5235, 5246, 'WORKFROM'],
#     [5249, 5257, 'WORKTO'],
#     [5279, 5308, 'POSITION'],
#     [5310, 5342, 'ORG'],
#     [5358, 5490, 'SUMMARY'],
#     [5674, 5685, 'WORKFROM'],
#     [5688, 5700, 'WORKTO'],
#     [5709, 5717, 'POSITION'],
#     [5719, 5744, 'ORG'],
#     [5760, 5928, 'SUMMARY'],
#     [5943, 6119, 'ACHIEVEMENTS'],
#     [6121, 6132, 'WORKFROM'],
#     [6135, 6147, 'WORKTO'],
#     [6168, 6199, 'POSITION'],
#     [6201, 6232, 'ORG'],
#     [6248, 6349, 'SUMMARY'],
#     [6408, 6416, 'WORKFROM'],
#     [6419, 6430, 'WORKTO'],
#     [6450, 6487, 'POSITION'],
#     [6489, 6511, 'ORG'],
#     [6527, 6585, 'SUMMARY'],
#     [6650, 6659, 'WORKFROM'],
#     [6662, 6671, 'WORKTO'],
#     [6690, 6716, 'POSITION'],
#     [6718, 6762, 'ORG'],
#     [6778, 7025, 'SUMMARY'],
#     [7177, 7186, 'WORKFROM'],
#     [7189, 7198, 'WORKTO'],
#     [7207, 7230, 'POSITION'],
#     [7232, 7245, 'ORG'],
#     [7261, 7507, 'SUMMARY'],
#     [7772, 7790, 'EDUCATION'],
#     [7807, 7811, 'YEAROFGRAD'],
#     [7945, 8018, 'SPEC'],
#     [7813, 7869, 'INTER'],
#     [8997, 9026, 'LANG'],
#     [8063, 8628, 'SKILLS'],
#     [8654, 8777, 'SKILLS']]}],
#  ['Николай Андреевич Тагиров. Контакты: escalader2002@gmail.com, +7(967)5340962\r\nСоискатель скрыл дату рождения, высшее образование\r\nМосква\r\nГражданство: Россия\r\nРазработчик технической документации / Технический писатель\r\nНеполная дистанционная, удаленная работа, не готов к\xa0командировкам\r\nПо договорённости\r\nОпыт работы 6 лет\xa0и\xa08 месяцев\r\nФевраль\xa02018 – работает\xa0сейчас\r\n4 года\xa0и\xa03 месяца\r\nЗаместитель начальника технического отдела\r\nLLC "MTK Bussines.Optima"\r\nОбязанности:\r\nКонсультирование отдела продаж по техническим аспектам деятельности компании.\r\nРазработка технических решений для технико-коммерческих предложений.\r\nВедение послепродажной технической поддержки на поставленное оборудование и работы компании;\r\nРазработка и проверка документации на импортное и отечественное оборудование в соответствии с нормами РФ;\r\nКонсультирование инженеров по работе оборудования для мониторинга, передачи данных, основному энергетическому оборудованию, оборудованию для автоматизации и защиты основного оборудования и т. п.\r\nФевраль\xa02016 – работает\xa0сейчас\r\n6 лет\xa0и\xa03 месяца\r\nИнженер-проектировщик\r\nLLC "MTK Bussines.Optima"\r\nОбязанности:\r\nРазработка проектов по внедрению систем мониторинга основного оборудования на промышленных объектах и объектах ТЭК. Разработка технической документации на импортное и отечественное оборудование в соответствии с НТД РФ.\r\nСентябрь\xa02015 – февраль\xa02016\r\n6 месяцев\r\nИнженер\r\nООО "ЭЗОП"\r\nОбязанности:\r\nПроведение натурных измерений на энергетических и промышленных объектах, выполнение расчётов в специализированных ПО по ЭМС, составление протоколов, отчётов о состоянии ЭМС с выдачей рекомендаций.\r\nОбразование\r\nВысшее образование\r\n2015\r\nИвановский государственный энергетический университет им. В.И. Ленина, Иваново (Ивановская область)\r\nФакультет: ЭЭФ\r\nСпециальность: Высоковольтная электроэнергетика и электротехника\r\nВысшее образование\r\n2010\r\nГОУ СПО "Ивановский энергетический колледж"\r\nФакультет: Электрические станции, сети и системы\r\nСпециальность: Эксплуатация электроустановое\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nПроектирование, AutoCAD, Разработка проектной документации, Пользователь ПК, Проектная документация, нормативно-техническая документация, Работа с большим объемом информации, разработка нормативных документов, Разработка технических заданий, MS Office, MS Visio, Деловая переписка, Поиск информации в интернет, ГОСТы серий 19, 21, 34, 87 Постановление, ЕСКД, СПДС, ЕСПД, НИОКР, Видеонаблюдение.\r\nДополнительные сведения:\r\nЗнание основных серий ГОСТов на разработку документации, техническая грамотность, умение работать с большим объёмом информации, педантичность, высокие знания текстовых и графических редакторов, большой опыт работы с промышленным оборудованием и оборудованием для автоматизации, грамотная письменная речь, большой опыт разработки технической документации (проектной, конструкторской, эксплуатационной, исполнительной, пусковой).\r\nИностранные языки\r\nАнглийский язык — базовый',
#   {'entities': [[0, 25, 'NAME'],
#     [62, 76, 'PHONE'],
#     [130, 136, 'CITY'],
#     [37, 60, 'EMAIL'],
#     [319, 336, 'WOEXP'],
#     [78, 108, 'AGE'],
#     [220, 286, 'WORKCONDITIONS'],
#     [288, 305, 'SALARY'],
#     [159, 218, 'VACANCY'],
#     [110, 128, 'EDUCATION'],
#     [338, 350, 'WORKFROM'],
#     [353, 368, 'WORKTO'],
#     [389, 431, 'POSITION'],
#     [433, 458, 'ORG'],
#     [474, 1018, 'SUMMARY'],
#     [1020, 1032, 'WORKFROM'],
#     [1035, 1050, 'WORKTO'],
#     [1070, 1091, 'POSITION'],
#     [1093, 1118, 'ORG'],
#     [1134, 1352, 'SUMMARY'],
#     [1354, 1367, 'WORKFROM'],
#     [1370, 1382, 'WORKTO'],
#     [1395, 1402, 'POSITION'],
#     [1404, 1414, 'ORG'],
#     [1430, 1626, 'SUMMARY'],
#     [1641, 1659, 'EDUCATION'],
#     [1661, 1665, 'YEAROFGRAD'],
#     [1799, 1848, 'SPEC'],
#     [1850, 1868, 'EDUCATION'],
#     [1870, 1874, 'YEAROFGRAD'],
#     [1986, 2015, 'SPEC'],
#     [1667, 1766, 'INTER'],
#     [1876, 1919, 'INTER'],
#     [2930, 2955, 'LANG'],
#     [2060, 2454, 'SKILLS'],
#     [2482, 2909, 'SKILLS']]}],
#  ['Альберт Игоревич Бендиков. Контакты: merycism2061@gmail.com, +7(914)3123757\r\n59 лет (родился 14 августа 1962), высшее образование, не состоит в браке, детей нет\r\nМосква, \r\nЯсенево\r\nТехнический писатель\r\nНе готов к\xa0командировкам\r\nПо договорённости\r\nОпыт работы 22 года\xa0и\xa03 месяца\r\nДекабрь\xa02019 – январь\xa02020\r\n2 месяца\r\nТехнический писатель\r\nНПО "Гамма", Москва\r\nИнформационная безопасность\r\nОбязанности:\r\nУчастие в разработке документации согласно ЕСКД\r\nАвгуст\xa02012 – январь\xa02018\r\n5 лет\xa0и\xa06 месяцев\r\nТехнический писатель\r\n"Порядок цифр", Москва\r\nhttp://www.ordit.ru\r\nИнформационные технологии\r\nОбязанности:\r\nРазработка пользовательской и проектной документации (жалоб на которую не поступало); участие в тестировании программных продуктов; решение нетрадиционных задач\r\nМай\xa02010 – август\xa02012\r\n2 года\xa0и\xa04 месяца\r\nТехнический писатель\r\nООО "ВУЛКАН", Москва\r\nОбязанности:\r\nРазработка технической документации на разрабатываемые программные средства. Написание пресс-релизов и других материалов рекламного характера.\r\nЯнварь\xa02001 – апрель\xa02009\r\n8 лет\xa0и\xa04 месяца\r\nТехнический писатель\r\nCognitive Technologies, Москва\r\nОбязанности:\r\nРазработка технической документации на разрабатываемые программные средства. Создание справочных систем формата WinHelp и HTML help. Корректура и редактирование текстов отдела по связям с общественностью.\r\nЯнварь\xa01995 – декабрь\xa02000\r\n6 лет\r\nПрограммист\r\nCognitive Technologies, Москва\r\nОбязанности:\r\nРабота в среде Visual C+ + c использованием подпрограмм СУБД «Ника»\r\nОбразование\r\nВысшее образование\r\nДневная/Очная\r\n1984\r\nРоссийский государственный университет нефти и газа имени И.М.Губкина\r\nФакультет: Автоматики и вычислительной техники\r\nСпециальность: Прикладная математика\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nОсвоил турецкий шрифт - могу печатать и произносить напечатанные слова.\r\n\r\nКомпьютерные навыки:\r\nРабота в операционных системах MS DOS и MS Windows с использованием MS Office; MS Visual Studio 1.5; разработка справочных систем с помощью Help Compiler Workshop; HTML Workshop; Help & Manual\r\nДополнительные сведения:\r\n"военная история миров реальных и вымышленных" да водный туризм\r\nИностранные языки\r\nАнглийский язык — разговорный',
#   {'entities': [[0, 25, 'NAME'],
#     [61, 75, 'PHONE'],
#     [162, 168, 'CITY'],
#     [37, 59, 'EMAIL'],
#     [260, 278, 'WOEXP'],
#     [77, 83, 'AGE'],
#     [203, 227, 'WORKCONDITIONS'],
#     [229, 246, 'SALARY'],
#     [111, 129, 'CITY'],
#     [280, 292, 'WORKFROM'],
#     [295, 306, 'WORKTO'],
#     [318, 338, 'POSITION'],
#     [340, 359, 'ORG'],
#     [404, 451, 'SUMMARY'],
#     [453, 464, 'WORKFROM'],
#     [467, 478, 'WORKTO'],
#     [499, 519, 'POSITION'],
#     [521, 543, 'ORG'],
#     [607, 767, 'SUMMARY'],
#     [769, 777, 'WORKFROM'],
#     [780, 791, 'WORKTO'],
#     [812, 832, 'POSITION'],
#     [834, 854, 'ORG'],
#     [870, 1012, 'SUMMARY'],
#     [1014, 1025, 'WORKFROM'],
#     [1028, 1039, 'WORKTO'],
#     [1059, 1079, 'POSITION'],
#     [1081, 1111, 'ORG'],
#     [1127, 1331, 'SUMMARY'],
#     [1333, 1344, 'WORKFROM'],
#     [1347, 1359, 'WORKTO'],
#     [1368, 1379, 'POSITION'],
#     [1381, 1411, 'ORG'],
#     [1427, 1494, 'SUMMARY'],
#     [1509, 1527, 'EDUCATION'],
#     [1544, 1548, 'YEAROFGRAD'],
#     [1684, 1705, 'SPEC'],
#     [1550, 1619, 'INTER'],
#     [2151, 2180, 'LANG'],
#     [1750, 1821, 'SKILLS'],
#     [1847, 2039, 'SKILLS']]}],
#  ['Алиса Михайловна Ситнянская. Контакты: alboranite1856@list.ru, +7(919)8095070\r\n54 года (родилась 30 ноября 1967), среднее специальное, не состоит в браке, детей нет\r\nМосква, \r\nКрасногвардейская\r\nГражданство: Россия\r\nРаботник архива технической документации микроэлектроники авиастроения, ракетостроения\r\nПолная занятость, готова к\xa0командировкам\r\nВакцинирован(а). Есть сертификат\r\n30\xa0000\xa0руб.\r\nОпыт работы 3 года\xa0и\xa09 месяцев\r\nЯнварь\xa02012 – сентябрь\xa02015\r\n3 года\xa0и\xa09 месяцев\r\nСпециалист в архиве, технической документации\r\nМосковский завод электромеханической аппаратуры, Москва\r\nhttp://mzema.ru\r\nОбязанности:\r\nПодбор и выдача технической документации;выдача и прием технической документации;хранение технической документации;имеется третья форма секретности;взаимодействие с техническим бюро;ведение архива аналогично как в библиотеке;знание перечня технической документации в таких областях как микроэлектроника приборостроение авиастроение ракетостроение и так далее\r\nДостижения:\r\nУмение общаться с людьми; не конфликтность\r\nОбразование\r\nСреднее специальное образование\r\nДневная/Очная\r\n1986\r\nСпту 166 полиграфистов\r\nФакультет: Микроэлектроника\r\nСпециальность: Оператор вакуумного напыления-работала измерителем электрических параметров микромодулей и мозаичного резистора\r\nИностранные языки\r\nНемецкий язык — базовый',
#   {'entities': [[0, 27, 'NAME'],
#     [63, 77, 'PHONE'],
#     [166, 172, 'CITY'],
#     [39, 61, 'EMAIL'],
#     [405, 423, 'WOEXP'],
#     [79, 86, 'AGE'],
#     [304, 344, 'WORKCONDITIONS'],
#     [380, 390, 'SALARY'],
#     [216, 302, 'VACANCY'],
#     [114, 133, 'EDUCATION'],
#     [425, 436, 'WORKFROM'],
#     [439, 452, 'WORKTO'],
#     [474, 519, 'POSITION'],
#     [521, 576, 'ORG'],
#     [609, 967, 'SUMMARY'],
#     [1039, 1070, 'EDUCATION'],
#     [1161, 1272, 'SPEC'],
#     [1087, 1091, 'YEAROFGRAD'],
#     [1293, 1316, 'LANG'],
#     [1093, 1115, 'INTER']]}],
#  ['Герасим Петрович Шарликов. Контакты: verdurer1806@mail.ru, +7(928)3546145\r\n27 лет (родился 19 мая 1994), среднее специальное\r\nКараганда, готов\xa0к\xa0переезду: Москва, Нижний Новгород\xa0и ещё 2 города\r\nFrontend developer\r\nПолная занятость, удаленная работа, готов к\xa0командировкам\r\nВакцинирован(а). Есть сертификат\r\n80\xa0000\xa0руб.\r\nОпыт работы 5 месяцев\r\nДекабрь\xa02021 – работает\xa0сейчас\r\n5 месяцев\r\nReact разработчик\r\nАмакидс, Москва\r\nhttp://amakids.ru\r\nСеть развивающихся детских центров по обучению ментальной арифметике, скорочтению, развитию умственных способностей.\r\nОбязанности:\r\nРазработка обучающий игр\r\nОбразование\r\nСреднее специальное образование\r\nДневная/Очная\r\n2012\r\nСаранский гуманитарно-технический коллдеж\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nЕсть опыт:\r\n\r\nКросс-браузерной и адаптивной верстки.\r\nРазработки SPA на Vanilla JS, React.\r\nТак же приходилось использовать:TypeScript, Mongo DB, Redux, REST API, систему контроля версий Git, БЭМ\r\nУчаствовал в командной разработки.\r\nSkills:\r\n\r\nHTML5, CSS3, SCSS\r\nJavaScript, Typescript\r\nReact, React-hooks\r\nRedux-thunk\r\nGitHub\r\nFigma, Photoshop, Postman, WebStorm\r\nWebpack, Prettier, Eslint\r\nДополнительные сведения:\r\nВ планах на ближайшее будущее познакомить себя с Node.JS\r\n\r\nС удовольствием расскажу о себе намного больше в формате живого общения\r\nИностранные языки\r\nАнглийский язык — базовый',
#   {'entities': [[0, 25, 'NAME'],
#     [59, 73, 'PHONE'],
#     [126, 135, 'CITY'],
#     [37, 57, 'EMAIL'],
#     [333, 342, 'WOEXP'],
#     [75, 81, 'AGE'],
#     [137, 193, 'WORKCONDITIONS'],
#     [215, 272, 'WORKCONDITIONS'],
#     [105, 124, 'EDUCATION'],
#     [195, 213, 'VACANCY'],
#     [308, 318, 'SALARY'],
#     [344, 356, 'WORKFROM'],
#     [359, 374, 'WORKTO'],
#     [387, 404, 'POSITION'],
#     [406, 421, 'ORG'],
#     [574, 598, 'SUMMARY'],
#     [613, 644, 'EDUCATION'],
#     [661, 665, 'YEAROFGRAD'],
#     [667, 708, 'INTER'],
#     [1323, 1348, 'LANG'],
#     [753, 1143, 'SKILLS'],
#     [1171, 1227, 'SKILLS']]}],
#  ['Дарья Ивановна Родзеева. Контакты: wound1987@bk.ru, +7(949)9616544\r\n35 лет (родился 25 марта 1987), высшее образование\r\nЖелезнодорожный, готов\xa0к\xa0переезду: Екатеринбург, Красноярск\xa0и ещё 3 города\r\nГражданство: Россия\r\nНачинающий junior программист (frontend разработчик)\r\nУдаленная работа, не готов к\xa0командировкам\r\n60\xa0000\xa0руб.\r\nОпыт работы 14 лет\xa0и\xa02 месяца\r\nСентябрь\xa02014 – работает\xa0сейчас\r\n7 лет\xa0и\xa08 месяцев\r\nАдминистратор сервисного центра\r\nInksystem\r\nОбязанности:\r\n- Организация работы сервисного центра в целом\r\n- Ведение учета в 1C\r\n- Работа с CRM Битрикс-24\r\n- Работа с клиентами\r\nСентябрь\xa02010 – май\xa02014\r\n3 года\xa0и\xa09 месяцев\r\nИнженер-программист\r\nЛан\r\nОбязанности:\r\n- Паевание земель\r\n- Вынос участка по координатам\r\n- Работа с геоезическими координатами и Google Maps\r\nСентябрь\xa02006 – май\xa02009\r\n2 года\xa0и\xa09 месяцев\r\nИнженер-программист\r\nЛуганский Национальный Университет имени Тараса Шевченка\r\nОбязанности:\r\n- Наполнение сайта кафедры\r\n- Опыт работы в MySql\r\n- Сборка курсов для дистанционного обучения студентов\r\nОбразование\r\nВысшее образование\r\n2012\r\nЛуганский национальный аграрный университет, Луганск\r\nФакультет: Кафедра землеустройства\r\nСпециальность: Землеустройство и кадастры\r\nВысшее образование\r\n2009\r\nЛуганский Национальный Университет имени Тараса Шевченка\r\nФакультет: Институт информационных технологий\r\nСпециальность: Программное обеспечение вычислительной техники и автоматизированных систем\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nИсполнительность, JavaScript, HTML, CSS, jQuery, MySQL, PHP, Git, Joomla CMS, CMS Wordpress, ООП, Borland Delphi, SQL, Web Application Development, 1С-Битрикс\r\nДополнительные сведения:\r\nВоспитанный, организованный, самообучаем. Желаю развиваться, как профессионал, работая со специалистами, которые умеют писать код. Всегда готов обучаться новому.\r\n\r\nЗнание HTML, CSS, JavaScript, PHP 7+, работа с Git, webpack,1с-Битрикс.\r\nРазработка на Symfony.\r\nКонфигурирование nginx.\r\nБазовые знания SQL, Linux, bush и реляционных БД, так же React и Vue.\r\nPython на уровне простых скриптов.\r\nBackend программирование.\r\n\r\nСайт с примерами работ\r\nanatoly-test-page.xyz\r\nИностранные языки\r\nАнглийский язык — разговорный\r\nУкраинский язык — cвободное владение\r\nВодительские права\r\nB — легковые авто',
#   {'entities': [[0, 23, 'NAME'],
#     [52, 66, 'PHONE'],
#     [120, 135, 'CITY'],
#     [35, 50, 'EMAIL'],
#     [340, 357, 'WOEXP'],
#     [68, 74, 'AGE'],
#     [271, 313, 'WORKCONDITIONS'],
#     [137, 194, 'WORKCONDITIONS'],
#     [315, 325, 'SALARY'],
#     [217, 269, 'VACANCY'],
#     [100, 118, 'EDUCATION'],
#     [359, 372, 'WORKFROM'],
#     [375, 390, 'WORKTO'],
#     [411, 442, 'POSITION'],
#     [444, 453, 'ORG'],
#     [469, 586, 'SUMMARY'],
#     [588, 601, 'WORKFROM'],
#     [604, 612, 'WORKTO'],
#     [634, 653, 'POSITION'],
#     [655, 658, 'ORG'],
#     [674, 776, 'SUMMARY'],
#     [778, 791, 'WORKFROM'],
#     [794, 802, 'WORKTO'],
#     [824, 843, 'POSITION'],
#     [845, 901, 'ORG'],
#     [917, 1021, 'SUMMARY'],
#     [1036, 1054, 'EDUCATION'],
#     [1056, 1060, 'YEAROFGRAD'],
#     [1167, 1193, 'SPEC'],
#     [1195, 1213, 'EDUCATION'],
#     [1215, 1219, 'YEAROFGRAD'],
#     [1341, 1415, 'SPEC'],
#     [1062, 1114, 'INTER'],
#     [1221, 1277, 'INTER'],
#     [1460, 1618, 'SKILLS'],
#     [1646, 2065, 'SKILLS'],
#     [2135, 2202, 'LANG'],
#     [2069, 2114, 'SKILLS']]}],
#  ['Валентина Николаевна Алашинова. Контакты: sidebones2033@list.ru, +7(957)7915670\r\n31 год (родился 30 января 1991), высшее образование\r\nВеликий Новгород, готов\xa0к\xa0переезду: Москва, Санкт-Петербург\xa0и ещё 1 город\r\nГражданство: Россия\r\nJunior Java Developer\r\nПолная занятость, удаленная работа, готов к\xa0командировкам\r\nВакцинирован(а). Есть сертификат\r\n50\xa0000\xa0руб.\r\nОбразование\r\nМагистр\r\nДневная/Очная\r\n2014\r\nНовгородский государственный университет имени Ярослава Мудрого\r\nФакультет: Институт электронных и информационных систем\r\nСпециальность: Прикладная математика и информатика\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\n1. Разработка приложений на Java.\r\n2. Применение Java Collections.\r\n3. Разработка веб-приложений с использованием Spring, Spring Security, Spring Boot и Hibernate.\r\n4. Работа с Maven.\r\n5. Вёрстка веб-страниц на HTML с использованием CSS и JavaScript.\r\n6. Работа с Git.\r\n7. Базовая работа с SQL.\r\n8. Применение MVC.\r\nДополнительные сведения:\r\nИспользую Eclipse и IntelliJ IDEA. Читаю и пишу на английском.\r\n\r\nСейчас изучаю:\r\n1. Spring Data.\r\n2. Gradle и Ant.\r\n3. Linux.\r\n\r\nБуду изучать:\r\n1. Spring Cloud.\r\n2. Тестирование в Java.\r\n3. Jenkins, Kubernetes и Docker.\r\n4. Python.\r\n\r\nВыполненные демо-проекты:\r\nhttps://github.com/irimitladder/spring-boot-demo\r\nhttps://github.com/irimitladder/spring-rest-demo\r\nhttps://github.com/irimitladder/spring-security-demo\r\nИностранные языки\r\nАнглийский язык — технический',
#   {'entities': [[0, 30, 'NAME'],
#     [65, 79, 'PHONE'],
#     [134, 150, 'CITY'],
#     [42, 63, 'EMAIL'],
#     [81, 87, 'AGE'],
#     [253, 310, 'WORKCONDITIONS'],
#     [152, 207, 'WORKCONDITIONS'],
#     [114, 132, 'EDUCATION'],
#     [230, 251, 'VACANCY'],
#     [346, 356, 'SALARY'],
#     [372, 379, 'EDUCATION'],
#     [396, 400, 'YEAROFGRAD'],
#     [539, 574, 'SPEC'],
#     [402, 465, 'INTER'],
#     [1397, 1426, 'LANG'],
#     [619, 933, 'SKILLS'],
#     [961, 1023, 'SKILLS'],
#     [1027, 1087, 'SKILLS'],
#     [1091, 1193, 'SKILLS'],
#     [1197, 1376, 'SKILLS']]}],
#  ['Виктор Василиевич Гурушкин. Контакты: snakebite1832@mail.ru, +7(927)5770067\r\n51 год (родилась 01 января 1971), высшее образование\r\nВолгоград, готова\xa0к\xa0переезду: Москва, Тула\r\nГражданство: Россия\r\nReact разработчик (junior, стажёр)\r\nПолная занятость, удаленная работа, готова к\xa0командировкам\r\nВакцинирован(а). Есть сертификат\r\n30\xa0000\xa0руб.\r\nОпыт работы 25 лет\xa0и\xa09 месяцев\r\nАвгуст\xa01997 – апрель\xa02020\r\n22 года\xa0и\xa09 месяцев\r\nИнженер электросвязи 2 категории\r\nРостелеком, Волгоград\r\nhttp://www.rostelecom.ru\r\nИнтернет-провайдер, Оптоволоконная связь, Фиксированная связь, Мобильная связь\r\nОбязанности:\r\n- мониторинг сети передачи данных,\r\n- техническая поддержка клиентов сети,\r\n- сопровождение и администрирование системы IP-телефонии,\r\n- ведение технической документации сети,\r\n- администрирование системы мониторинга IBM Tivoly Netcool,\r\n- 3-я линия технической поддержки клиентов сети передачи данных,\r\n- настройка оборудования сети: коммутаторов, маршрутизаторов, DSLAM, GPON.\r\nАвгуст\xa01994 – август\xa01997\r\n3 года\xa0и\xa01 месяц\r\nИнженер кафедры алгебры, геометрии и вычислительной техники\r\nВолгоградский государственный педагогический университет (Волгоградский государственный социально-педагогический университет), Москва\r\nВуз, ссуз колледж, ПТУ\r\nОбязанности:\r\n- сопровождение и обслуживание средств вычислительной техники в учебной аудитории;\r\n- совместительство - ассистент кафедры. Обязанности - проведение практических занятий у студентов по предметам: алгебра, геометрия, информатика.\r\nОбразование\r\nВысшее образование\r\n2003\r\nВолгоградский государственный технический университет, Волгоград\r\nФакультет: 2-го высщего образования\r\nСпециальность: Вычислительный машины, комплексы, системы и сети\r\nВысшее образование\r\n1994\r\nВолгоградский государственный педагогический университет (Волгоградский государственный социально-педагогический университет), Волгоград\r\nФакультет: Математика, информатика и вычислительная техника\r\nСпециальность: Учитель математики, информатики и вычислительной техники\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nАдминистрирование сетевого оборудования, Сопровождение клиентов, Автоматизированное рабочее место (АРМ), Настройка сетевых подключений, Клиентоориентированность, Информационные технологии\r\nДополнительные сведения:\r\n- имею навыки работы с оборудованием следующих производителей:\r\nCisco, Juniper, Qtech, Edge-Core, ZyXEL, D-link, Nateks, Huawei и др.;\r\n- есть стремление к обучению, повышению профессионального уровня;\r\n- настроенность на достижение цели, выполнение поставленных задач;\r\n- ответственность.\r\nИностранные языки\r\nАнглийский язык — базовый',
#   {'entities': [[0, 26, 'NAME'],
#     [61, 75, 'PHONE'],
#     [131, 140, 'CITY'],
#     [38, 59, 'EMAIL'],
#     [351, 369, 'WOEXP'],
#     [196, 230, 'WORKCONDITIONS'],
#     [326, 336, 'SALARY'],
#     [77, 83, 'AGE'],
#     [142, 173, 'WORKCONDITIONS'],
#     [232, 290, 'WORKCONDITIONS'],
#     [111, 129, 'EDUCATION'],
#     [371, 382, 'WORKFROM'],
#     [385, 396, 'WORKTO'],
#     [419, 451, 'POSITION'],
#     [453, 474, 'ORG'],
#     [596, 974, 'SUMMARY'],
#     [976, 987, 'WORKFROM'],
#     [990, 1001, 'WORKTO'],
#     [1021, 1080, 'POSITION'],
#     [1082, 1215, 'ORG'],
#     [1255, 1483, 'SUMMARY'],
#     [1498, 1516, 'EDUCATION'],
#     [1518, 1522, 'YEAROFGRAD'],
#     [1642, 1690, 'SPEC'],
#     [1524, 1588, 'INTER'],
#     [1692, 1710, 'EDUCATION'],
#     [1712, 1716, 'YEAROFGRAD'],
#     [1932, 1988, 'SPEC'],
#     [1718, 1854, 'INTER'],
#     [2558, 2583, 'LANG'],
#     [2033, 2220, 'SKILLS'],
#     [2248, 2537, 'SKILLS']]}],
#  ['Кристина Петровна Сельникова. Контакты: everard1874@yandex.ru, +7(933)9679459\r\n42 года (родился 14 июня 1979), высшее образование\r\nНовосибирск, готов\xa0к\xa0переезду: Москва, Самара\xa0и ещё 16 городов\r\nBackend Python Developer\r\nПолная занятость, удаленная работа, готов к\xa0командировкам\r\nПо договорённости\r\nОпыт работы 20 лет\xa0и\xa04 месяца\r\nЯнварь\xa02002 – работает\xa0сейчас\r\n20 лет\xa0и\xa04 месяца\r\nСтарший научный сотрудник\r\nИФП СОРАН, Новосибирск\r\nОбразование\r\nКандидат наук\r\nДневная/Очная\r\n2002\r\nНовосибирский государственный технический университет\r\nФакультет: РЭФ\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nГрафические редакторы: T-Flex, CorelDRAW;\r\nМатематические пакеты: MathCad;\r\nЯзыки программирования: Basic, Fortran, Pascal, Scheme SQL, Git, Python (meep, numpy, pandas, camfr, matplotlib, aiohttp, marshmallow, PostgreSQL, docker, poetry, swagger, telepot, ngrok, asyncio, API, pytest, unittest)\r\nОпыт коммерческой разработки: стажировка 2 месяца в ЦФТ, написание ботов для telegram и discord.\r\nСредства разработки ПО: LabView.\r\nИностранные языки\r\nАнглийский язык — разговорный',
#   {'entities': [[0, 28, 'NAME'],
#     [63, 77, 'PHONE'],
#     [131, 142, 'CITY'],
#     [40, 61, 'EMAIL'],
#     [311, 328, 'WOEXP'],
#     [221, 278, 'WORKCONDITIONS'],
#     [144, 193, 'WORKCONDITIONS'],
#     [280, 297, 'SALARY'],
#     [195, 219, 'VACANCY'],
#     [79, 86, 'AGE'],
#     [111, 129, 'EDUCATION'],
#     [330, 341, 'WORKFROM'],
#     [344, 359, 'WORKTO'],
#     [380, 405, 'POSITION'],
#     [407, 429, 'ORG'],
#     [444, 457, 'EDUCATION'],
#     [474, 478, 'YEAROFGRAD'],
#     [480, 533, 'INTER'],
#     [1042, 1071, 'LANG'],
#     [594, 1021, 'SKILLS']]}],
#  ['Георгий Андреевич Челиков. Контакты: experimentalist1997@list.ru, +7(917)5673577\r\n27 лет (родился 17 июля 1994), высшее образование\r\nМосква\r\nПрограммист-стажер\r\nПолная занятость, готов к\xa0командировкам\r\nПо договорённости\r\nОбразование\r\nВысшее образование\r\nДневная/Очная\r\n2018\r\nРоссийский химико-технологический университет имени Д.И.Менделеева\r\nФакультет: Нпм\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nJava core\r\nИностранные языки\r\nАнглийский язык — технический',
#   {'entities': [[0, 25, 'NAME'],
#     [66, 80, 'PHONE'],
#     [133, 139, 'CITY'],
#     [37, 64, 'EMAIL'],
#     [82, 88, 'AGE'],
#     [161, 200, 'WORKCONDITIONS'],
#     [202, 219, 'SALARY'],
#     [141, 159, 'VACANCY'],
#     [113, 131, 'EDUCATION'],
#     [234, 252, 'EDUCATION'],
#     [269, 273, 'YEAROFGRAD'],
#     [275, 341, 'INTER'],
#     [432, 461, 'LANG'],
#     [402, 411, 'SKILLS']]}],
#  ['Анастасия Эдуардовна Мошенцева. Контакты: ustilaginaceous1836@bk.ru, +7(980)4993834\r\n31 год (родился 02 января 1991), высшее образование, не состоит в браке, детей нет\r\nМосква\r\nГражданство: Россия\r\nПрограммист\r\nГотов к\xa0командировкам\r\n100\xa0000\xa0руб.\r\nОпыт работы 8 лет\xa0и\xa03 месяца\r\nЯнварь\xa02021 – работает\xa0сейчас\r\n1 год\xa0и\xa04 месяца\r\nРепетитор\r\nФриланс, Москва\r\nОбучение\r\nОбязанности:\r\n- Обучение взрослых и детей разработке на Python c нуля\r\n- Сoпpoвoждении проeктов\r\n- Опыт работы как со взрослыми, так и с детьми\r\n- Самостоятельный поиск и развитие клиентов\r\nСентябрь\xa02019 – работает\xa0сейчас\r\n2 года\xa0и\xa08 месяцев\r\nWeb-разработчик, маркетолог\r\nФриланс (разработка сайтов и рекламных кампаний под них самостоятельно), Москва\r\nОбязанности:\r\n- Создание полноценных сайтов и лэндингов с нуля при помощи языков программирования JavaScript в связке HTML/CSS, Python.\r\n\r\n- Разработка рекламных кампаний (контекстная реклама) в Яндекс.Директе, Google Adwords.\r\n\r\n- Разработка таргетированной рекламы в социальных сетях.\r\n\r\n- Развитие отношений с существующей партнерской базой, поддержание постоянных контактов с партнерами.\r\n\r\n- Создание и развитие собственной партнерской базы.\r\n\r\n- Активный поиск клиентов.\r\n\r\n- Ведение клиентской базы.\r\n\r\n- Полное сопровождение сделки.\r\n\r\n- Мониторинг и анализ эффективности кампаний.\r\n\r\n- Контроль бюджетов рекламных кампаний.\r\nНоябрь\xa02020 – ноябрь\xa02021\r\n1 год\xa0и\xa01 месяц\r\nВедущий инженер ПТО\r\nСвязьстройдеталь, ЗАО, Москва\r\nhttp://ssd.ru\r\nОборудование и станки для металлургии и металлообработки (производство), Оборудование и станки для отраслей легкой промышленности (производство), Оптоволоконная связь\r\nОбязанности:\r\n- Обеспечение технологической подготовки производства покрытия деталей НЗП и изделий из металла методами порошковой окраски, гальванирования, термодиффузионного цинкования.\r\n\r\n- Работа цехового технолога, постановка технологий, контроль тех. дисциплины, управление производственным коллективом свыше 15 человек.\r\n\r\n- Выполнение технических расчетов, подбор оснастки и инструмента, разработка и сопровождение технологии защитного покрытия металлических поверхностей с установлением режимов обработки, норм расходования материалов.\r\n\r\n- Работа в информационных системах предприятия по созданию и корректировке структур, контроль за отклонениями установленных норм в списании материалов.\r\n\r\n- Разработка технологий, контроль за средствами технологического оснащения и инструментом.\r\n\r\n- Проверка КД на технологичность. Разработка технологических документов (маршрутных и операционных карт, типичных тех. процессов, инструкций, стандартов и т. д.);\r\n\r\n- Участие в разработке технических заданий на проектирование технологической оснастки, а также непосредственное проектирование или помощь в проектировании оснастки.\r\n\r\n- Работы по улучшению технологии, поиск и опробовании новых материалов, режимов переработки.\r\n\r\n- Участие в подборе нового оборудования и подготовке договоров на закупку.\r\n\r\n- Работа и программирование в ERP системе (планирование и управление ресурсами) - SyteLine, фирмы Frontstep. Система включает многоотраслевой характер, такой как: бух. учет, логистика, производство, строительство. Система, берущая свое начало от Американских истоков. Очень мощный инструмент по созданию бизнес-процессов.\r\n\r\n* Достижения в компании:\r\n\r\n- Успешный запуск и пуско-наладка участка порошковой окраски с нуля.\r\n\r\n- Усовершенствование технологических процессов и общего КПД работы на единицу изделия.\r\n\r\n- Мой полный контроль над подбором материала, поиску поставщиков и налаживанию связей с поставщиками для долгосрочного сотрудничества обеспечил отличные показатели по качественным характеристикам изделий.\r\n\r\n- Разработка и проектирование оснастки для производства, которое повысило уровень выработки на 36%.\r\n\r\n- Разработал на языке прогр ...
#   {'entities': [[0, 30, 'NAME'],
#     [69, 83, 'PHONE'],
#     [169, 175, 'CITY'],
#     [42, 67, 'EMAIL'],
#     [260, 276, 'WOEXP'],
#     [85, 91, 'AGE'],
#     [211, 232, 'WORKCONDITIONS'],
#     [234, 245, 'SALARY'],
#     [198, 209, 'VACANCY'],
#     [118, 136, 'EDUCATION'],
#     [278, 289, 'WORKFROM'],
#     [292, 307, 'WORKTO'],
#     [327, 336, 'POSITION'],
#     [338, 353, 'ORG'],
#     [379, 553, 'SUMMARY'],
#     [555, 568, 'WORKFROM'],
#     [571, 586, 'WORKTO'],
#     [608, 635, 'POSITION'],
#     [637, 716, 'ORG'],
#     [732, 1350, 'SUMMARY'],
#     [1352, 1363, 'WORKFROM'],
#     [1366, 1377, 'WORKTO'],
#     [1396, 1415, 'POSITION'],
#     [1417, 1446, 'ORG'],
#     [1645, 3256, 'SUMMARY'],
#     [3288, 4040, 'ACHIEVEMENTS'],
#     [4042, 4054, 'WORKFROM'],
#     [4057, 4069, 'WORKTO'],
#     [4089, 4120, 'POSITION'],
#     [4122, 4216, 'ORG'],
#     [4232, 5011, 'SUMMARY'],
#     [5043, 5708, 'ACHIEVEMENTS'],
#     [5710, 5721, 'WORKFROM'],
#     [5724, 5737, 'WORKTO'],
#     [5758, 5804, 'POSITION'],
#     [5806, 5861, 'NAME'],
#     [5877, 6725, 'SUMMARY'],
#     [6757, 7051, 'ACHIEVEMENTS'],
#     [7053, 7062, 'WORKFROM'],
#     [7065, 7077, 'WORKTO'],
#     [7098, 7170, 'POSITION'],
#     [7172, 7206, 'ORG'],
#     [7222, 7994, 'SUMMARY'],
#     [8026, 8322, 'ACHIEVEMENTS'],
#     [8324, 8336, 'WORKFROM'],
#     [8339, 8348, 'WORKTO'],
#     [8370, 8391, 'POSITION'],
#     [8393, 8429, 'ORG'],
#     [8445, 8841, 'SUMMARY'],
#     [8873, 9298, 'ACHIEVEMENTS'],
#     [9313, 9331, 'EDUCATION'],
#     [9333, 9337, 'YEAROFGRAD'],
#     [9453, 9475, 'SPEC'],
#     [9339, 9401, 'INTER'],
#     [11059, 11088, 'LANG'],
#     [9520, 9869, 'SKILLS'],
#     [10494, 11038, 'SKILLS'],
#     [9897, 10466, 'SKILLS']]}],
#  ['Анна Дмитриевна Прохладова. Контакты: bicamerist1871@gmail.com, +7(953)1480626\r\n30 лет (родился 03 мая 1991), высшее образование, cостоит в браке, детей нет\r\nМытищи\r\nГражданство: Россия\r\nJunior Java разработчик\r\nПолная занятость, готов к\xa0командировкам\r\nВакцинирован(а). Есть сертификат\r\n60\xa0000\xa0руб.\r\nОпыт работы 7 лет\xa0и\xa06 месяцев\r\nЯнварь\xa02022 – работает\xa0сейчас\r\n4 месяца\r\nМладший Java-разработчик\r\nYLab, Москва\r\nhttps://ylab.io\r\nРазработка высоконагруженных IT-проектов и автоматизация бизнес-процессов для коммерческого сектора и государственных структур.\r\nОбязанности:\r\nJava разработка\r\nДекабрь\xa02021 – январь\xa02022\r\n2 месяца\r\nСтажер Java\r\nYlab, Москва\r\nhttps://ylab.io\r\nРазработка высоконагруженных IT-проектов и автоматизация бизнес-процессов для коммерческого сектора и государственных структур.\r\nОбязанности:\r\nJava разработчик, обучение Maven, Spring, Atlassian, Gitlab, PostgreSQL\r\nАвгуст\xa02014 – август\xa02021\r\n7 лет\xa0и\xa01 месяц\r\nМенеджер по продажам\r\nСбербанк России\r\nОбразование\r\nВысшее образование\r\nДневная/Очная\r\n2013\r\nДимитровградский инженерно-технологический институт - филиал Национального исследовательского ядерного университета "МИФИ"\r\nФакультет: Прикладная математика и информатика\r\nСпециальность: Математик\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nIntellij idea\r\nДополнительные сведения:\r\nНачальные знания Java, spring, maven на курсах работал с PostgreSQL в gitLab\r\nИностранные языки\r\nАнглийский язык — базовый',
#   {'entities': [[0, 26, 'NAME'],
#     [64, 78, 'PHONE'],
#     [158, 164, 'CITY'],
#     [38, 62, 'EMAIL'],
#     [312, 329, 'WOEXP'],
#     [80, 86, 'AGE'],
#     [212, 251, 'WORKCONDITIONS'],
#     [287, 297, 'SALARY'],
#     [187, 210, 'VACANCY'],
#     [110, 128, 'EDUCATION'],
#     [331, 342, 'WORKFROM'],
#     [345, 360, 'WORKTO'],
#     [372, 396, 'POSITION'],
#     [398, 410, 'ORG'],
#     [572, 587, 'SUMMARY'],
#     [589, 601, 'WORKFROM'],
#     [604, 615, 'WORKTO'],
#     [627, 638, 'POSITION'],
#     [640, 652, 'ORG'],
#     [814, 885, 'SUMMARY'],
#     [887, 898, 'WORKFROM'],
#     [901, 912, 'WORKTO'],
#     [931, 951, 'POSITION'],
#     [953, 968, 'ORG'],
#     [983, 1001, 'EDUCATION'],
#     [1018, 1022, 'YEAROFGRAD'],
#     [1211, 1220, 'SPEC'],
#     [1024, 1146, 'INTER'],
#     [1403, 1428, 'LANG'],
#     [1265, 1278, 'SKILLS'],
#     [1306, 1382, 'SKILLS']]}],
#  ['Алёна Алексеевна Кегеджиева. Контакты: haler1965@gmail.com, +7(975)8193432\r\n30 лет (родился 10 ноября 1991), высшее образование, не состоит в браке, детей нет\r\nМосква, \r\nМарьина роща\r\nГражданство: Россия\r\nПрограммист\r\nПолная занятость, готов к\xa0командировкам\r\nПрохожу вакцинацию\r\n70\xa0000\xa0руб.\r\nОпыт работы 4 года\r\nМарт\xa02019 – июнь\xa02020\r\n1 год\xa0и\xa04 месяца\r\nСпециалист 3 категории\r\nVFS Services, Москва\r\nhttps://france-visas.gouv.fr\r\nСфера деятельности - туризм. Работа заключалась в приеме и оформлении документов необходимых для получения французских виз, доставка их в Консульство, консультировании клиентов и объяснении работы сайта и визового центра.\r\nОбязанности:\r\nРабота заключалась в приеме и оформлении документов необходимых для получения французских виз, доставка их в Консульство, консультировании клиентов и объяснении работы сайта и визового центра.\r\nДекабрь\xa02015 – июль\xa02018\r\n2 года\xa0и\xa08 месяцев\r\nСпециалист\r\nФНС России, Москва\r\nОбразование\r\nВысшее образование\r\nДневная/Очная\r\n2014\r\nМосковский государственный технологический университет "Станкин"\r\nФакультет: ФЭМ\r\nСпециальность: Специальность: Экономика и управление на предприятии\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nУверенный пользователь ПК.\r\nЗнаю программы Excel, Word, Cloud, Парус и 1C.\r\nВладею языком программирования Python.\r\nСпокойно разговариваю на английском.\r\nИмею образование переводчика в сфере деловой коммуникации.\r\nМогу проводить оценку имущества.\r\nМогу делать анализ рынка и составлять бизнес - план.\r\nИностранные языки\r\nАнглийский язык — разговорный\r\nВодительские права\r\nB — легковые авто',
#   {'entities': [[0, 27, 'NAME'],
#     [60, 74, 'PHONE'],
#     [160, 166, 'CITY'],
#     [39, 58, 'EMAIL'],
#     [304, 310, 'WOEXP'],
#     [76, 82, 'AGE'],
#     [218, 257, 'WORKCONDITIONS'],
#     [279, 289, 'SALARY'],
#     [205, 216, 'VACANCY'],
#     [109, 127, 'EDUCATION'],
#     [312, 321, 'WORKFROM'],
#     [324, 333, 'WORKTO'],
#     [353, 375, 'POSITION'],
#     [377, 397, 'ORG'],
#     [666, 858, 'SUMMARY'],
#     [860, 872, 'WORKFROM'],
#     [875, 884, 'WORKTO'],
#     [906, 916, 'POSITION'],
#     [918, 936, 'ORG'],
#     [951, 969, 'EDUCATION'],
#     [986, 990, 'YEAROFGRAD'],
#     [1104, 1141, 'SPEC'],
#     [992, 1056, 'INTER'],
#     [1507, 1536, 'LANG'],
#     [1186, 1486, 'SKILLS']]}],
#  ['Виталий Георгиевич Гильманшин. Контакты: trafflike2050@yandex.ru, +7(903)1058632\r\n37 лет (родился 27 сентября 1984), высшее образование, не состоит в браке, детей нет\r\nМосква, \r\nЦарицыно\r\n, \r\nКантемировская\r\nГражданство: Россия\r\nПрограммист С++\r\nПолная занятость, не готов к\xa0командировкам\r\n30\xa0000\xa0руб.\r\nОпыт работы 3 года\xa0и\xa04 месяца\r\nДекабрь\xa02018 – март\xa02019\r\n4 месяца\r\nСпециалист товарного контроля\r\nООО "Вектрум-К", Москва\r\nПродажа электроники, компьютерных комплектующих и бытовой техники.\r\nОбязанности:\r\nКомплектование неисправного оборудования, комплектующих для последующей отправки в сервисные центры.\r\nДокументальное оформление данной процедуры в программе 1С:Предприятие.\r\nСентябрь\xa02018 – октябрь\xa02018\r\n2 месяца\r\nОператор сканирования\r\nООО "ЭЛАР", Москва\r\nРазработка ПО и консультирование\r\nОбязанности:\r\nСканирование архивных и исторических документов на профессиональной технике.\r\nКонтроль качества получаемых изображений.\r\nОбработка изображений с применением специализированных программ (ACDSee, Photoshop и др.)\r\nЯнварь\xa02018 – апрель\xa02018\r\n4 месяца\r\nИнженер\r\nООО "РСС", Москва\r\nРемонт компьютерной и периферийной техники\r\nОбязанности:\r\nПрием и первичная диагностика техники.\r\nВыдача оборудования из ремонта.\r\nОформление документов.\r\nКраткие технические консультации.\r\nМарт\xa02015 – август\xa02017\r\n2 года\xa0и\xa06 месяцев\r\nСтарший специалист\r\nАО "БИНБАНК Диджитал", Москва\r\nКредитная организация\r\nОбязанности:\r\nОбработка входящей корреспонденции.\r\nРаспечатка исходящих документов из СЭД.\r\nФормирование почтовых отправлений.\r\nОбеспечение жизнедеятельности офиса.\r\nОбразование\r\nВысшее образование\r\nДневная/Очная\r\n2010\r\nМосковская финансово-промышленная академия\r\nФакультет: Информационные технологии\r\nСпециальность: Безопасность информационных систем\r\nСреднее специальное образование\r\nДневная/Очная\r\n2006\r\nМосковский Электронно-Технологический Техникум\r\nСпециальность: 230101, Вычислительные машины, системы, комплексы и сети.\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nВладение языками программирования C/C++.\r\nСоздание приложений на фреймворке Qt.\r\nНавыки работы с сетью и базами данных SQL.\r\nРазработка графического интерфейса в ОС Linux.\r\nДополнительные сведения:\r\nОпыта работы в указанной должности не имею.\r\nНахожусь в процессе смены профессии.\r\nУвлекаюсь изучением языков программирования.\r\nВ свободное время работаю над учебными проектами.\r\nИностранные языки\r\nАнглийский язык — технический',
#   {'entities': [[0, 29, 'NAME'],
#     [66, 80, 'PHONE'],
#     [168, 174, 'CITY'],
#     [41, 64, 'EMAIL'],
#     [82, 88, 'AGE'],
#     [246, 288, 'WORKCONDITIONS'],
#     [290, 300, 'SALARY'],
#     [229, 244, 'VACANCY'],
#     [117, 135, 'EDUCATION'],
#     [315, 332, 'WOEXP'],
#     [334, 346, 'WORKFROM'],
#     [349, 358, 'WORKTO'],
#     [370, 399, 'POSITION'],
#     [401, 424, 'ORG'],
#     [508, 680, 'SUMMARY'],
#     [682, 695, 'WORKFROM'],
#     [698, 710, 'WORKTO'],
#     [722, 743, 'POSITION'],
#     [745, 763, 'ORG'],
#     [813, 1023, 'SUMMARY'],
#     [1025, 1036, 'WORKFROM'],
#     [1039, 1050, 'WORKTO'],
#     [1062, 1069, 'POSITION'],
#     [1071, 1088, 'ORG'],
#     [1148, 1278, 'SUMMARY'],
#     [1280, 1289, 'WORKFROM'],
#     [1292, 1303, 'WORKTO'],
#     [1325, 1343, 'POSITION'],
#     [1345, 1374, 'ORG'],
#     [1413, 1563, 'SUMMARY'],
#     [1578, 1596, 'EDUCATION'],
#     [1613, 1617, 'YEAROFGRAD'],
#     [1716, 1750, 'SPEC'],
#     [1619, 1661, 'INTER'],
#     [1752, 1783, 'EDUCATION'],
#     [1800, 1804, 'YEAROFGRAD'],
#     [1877, 1926, 'SPEC'],
#     [1806, 1852, 'INTER'],
#     [1971, 2142, 'SKILLS'],
#     [2369, 2398, 'LANG'],
#     [2170, 2348, 'SKILLS']]}],
#  ['Елена Сергеевна Хатылева. Контакты: armourer1835@yandex.ru, +7(967)3136223\r\n35 лет (родился 07 января 1987), высшее образование\r\nМосква\r\nГражданство: Россия\r\nПрограммист микроконтроллеров / разработчик электрических схем\r\nПолная занятость, удаленная работа, не готов к\xa0командировкам\r\nВакцинирован(а). Есть сертификат\r\nПо договорённости\r\nОпыт работы 14 лет\xa0и\xa010 месяцев\r\nМарт\xa02017 – работает\xa0сейчас\r\n5 лет\xa0и\xa02 месяца\r\nГлавный инженер проектов / Заведующий сектором интеграции\r\nНАМИ, ФГУП, Москва\r\nhttp://www.nami.ru\r\nНаучно-исследовательская, научная, академическая деятельность, Техническое обслуживание, ремонт автомобилей, Легковые, грузовые автомобили, мототехника, автобусы, троллейбусы (производство), Автокомпоненты, запчасти (производство)\r\nОбязанности:\r\n- разработка ТЗ на проект и его составные части, разработка ключевых технических решений;\r\n- руководство рабочими группами проекта (суммарно ~20 человек) - постановка задач разработчикам электрических схем и печатных плат, программистам, конструкторам, техническим писателям, контроль выполнения и анализ результатов проделанной работы;\r\n- разработка логики работы систем и отдельных компонентов, протоколов обмена данными, матриц коммуникации, системный анализ технических решений;\r\n- разработка программного обеспечения микроконтроллеров вспомогательных функциональных макетов.\r\n\r\nДостижения:\r\n- создание уникальных стендов для выполнения функциональных проверок электрики и электроники современных автомобилей;\r\n- разработана документация для создания электронной архитектуры нового автомобиля (электрические схемы, технические требования, CAN-матрицы, диаграммы состояний, диагностические спецификации);\r\n- разработана документация на интеллектуальные системы помощи водителю (ADAS).\r\nАвгуст\xa02009 – март\xa02017\r\n7 лет\xa0и\xa08 месяцев\r\nРуководитель направления / Ведущий инженер\r\nАО "ФЦНИВТ "СНПО "Элерон"\r\nhttp://www.eleron.ru\r\nГосударственные организации\r\nОбязанности:\r\nВедущий инженер (программирование микроконтроллеров):\r\n- разработка ПО для микроконтроллеров (МК) PIC от Microchip на языках С (Си) и ASM (ассемблер); имеется опыт работы со всеми линейками МК от Microchip (8-битные - PIC16, PIC18; 16-битные - PIC24, dsPIC30, dsPIC33; 32-битные - PIC32);\r\n- разработка низкоуровневого и управляющего ПО реального времени (уровень bare-metal - прямое управление регистрами МК);\r\n- разработка драйверов и работа с различной периферией МК (порты ввода-вывода, ADC, PWM, DMA, UART, SPI, I2C, CAN, Output compare, таймеры и т. д.);\r\n- разработка и реализация протоколов обмена данными;\r\n- разработка и реализация алгоритмов управления двигателями;\r\n- разработка и реализация алгоритмов системы контроля аккумуляторных батарей (заряд/разряд);\r\n- разработка и реализация цифровых фильтров;\r\n- разработка и реализация алгоритмов статистической обработки данных в реальном времени (вероятностные модели обнаружения различных веществ и материалов);\r\n- разработка и реализация алгоритмов взаимодействия с пользователем (меню, изображения, информационные сообщения, обработка органов управления);\r\n- отладка кода на "железе" с помощью внутрисхемного отладчика, мультиметра, осциллографа.\r\n\r\nВедущий инженер (разработчик электрических схем):\r\n- разработка электрических принципиальных схем (Э3) печатных плат;\r\n- разработка электрических схем соединений (Э4) устройств;\r\n- подбор элементной базы.\r\n\r\nВедущий инженер (технический писатель):\r\n- разработка технических условий (ТУ), инструкций по настройке и проверке (И16).\r\n\r\nРуководитель направления:\r\n- ведение НИОКР от этапа эскизного проекта до государственных испытаний.\r\n\r\nДостижения:\r\n- разработано программное обеспечение для обнаружителей различных веществ и материалов (металлы, радиоактивные и взрывчатые вещества), автоматизированных контрольно-пропускных устройств (кабины-шлюзы, турникет);\r\n- разработаны электрические схемы печатных п ...
#   {'entities': [[0, 24, 'NAME'],
#     [60, 74, 'PHONE'],
#     [129, 135, 'CITY'],
#     [36, 58, 'EMAIL'],
#     [349, 368, 'WOEXP'],
#     [318, 335, 'SALARY'],
#     [222, 282, 'WORKCONDITIONS'],
#     [76, 82, 'AGE'],
#     [158, 220, 'VACANCY'],
#     [109, 127, 'EDUCATION'],
#     [370, 379, 'WORKFROM'],
#     [382, 397, 'WORKTO'],
#     [417, 474, 'POSITION'],
#     [476, 494, 'ORG'],
#     [762, 1341, 'SUMMARY'],
# ...
#   {'entities': [[0, 31, 'NAME'],
#     [65, 79, 'PHONE'],
#     [134, 140, 'CITY'],
#     [43, 63, 'EMAIL'],
#     [266, 274, 'EDUCATION'],
#     [114, 132, 'EDUCATION'],
#     [291, 295, 'YEAROFGRAD'],
#     [361, 388, 'SPEC'],
#     [297, 306, 'INTER'],
#     [1042, 1071, 'LANG'],
#     [142, 191, 'VACANCY'],
#     [234, 251, 'SALARY'],
#     [193, 232, 'WORKCONDITIONS'],
#     [81, 87, 'AGE'],
#     [433, 1021, 'SKILLS']]}],
#  ['Алексей Викторович Бутанов. Контакты: caracal1987@yandex.ru, +7(924)3795280\r\n24 года (родился 02 марта 1998), среднее специальное, не состоит в браке, детей нет\r\nПодольск\r\nГражданство: Россия\r\nСистемный администратор\r\nПолная занятость, удаленная работа, не готов к\xa0командировкам\r\n40\xa0000\xa0руб.\r\nОпыт работы 1 год\xa0и\xa05 месяцев\r\nМай\xa02021 – март\xa02022\r\n11 месяцев\r\nСпециалист приема возвратов\r\nГК Аккорд, Подольск\r\nhttp://www.accordpost.ru\r\nЗАО "ГК Аккорд" – крупнейшая в России сервисная директ-маркетинговая компания.Много лет мы организуем для наших заказчиков маркетинговые рассылки по почте, проводим акции по программам лояльности, отправляем бизнес-документацию, комплектуем и отправляем посылки, производим и доставляем счета и квитанции.Наша миссия: выстраивать эффективный диалог между бизнесом и клиентом при помощи директ-маркетинга.Дистанционная торговля, банки, регистраторы, страховые компании и пенсионные фонды, коллекторы, ритейл, рекламные агентства – вот неполный перечень отраслей, в которых успешно используют услуги прямого маркетинга нашей компании.\r\nОбязанности:\r\nПрием и обработка возвратов, работа с накладными, работа с программой 1С\r\nОктябрь\xa02018 – март\xa02019\r\n6 месяцев\r\nПродавец-консультант\r\nBaon, Москва\r\nhttps://baon.ru\r\nПродажа женской и мужской одежды\r\nОбязанности:\r\nПродажа женской и мужской одежды, консультация\r\nОбразование\r\nСреднее специальное образование\r\n2018\r\nГБПОУ МО "Подольский колледж"\r\nСпециальность: Автомеханик\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nMicrosoft Office, 1С\r\nВодительские права\r\nB — легковые авто',
#   {'entities': [[0, 26, 'NAME'],
#     [61, 75, 'PHONE'],
#     [162, 170, 'CITY'],
#     [38, 59, 'EMAIL'],
#     [305, 322, 'WOEXP'],
#     [387, 406, 'ORG'],
#     [324, 332, 'WORKFROM'],
#     [335, 344, 'WORKTO'],
#     [358, 385, 'POSITION'],
#     [1082, 1154, 'SUMMARY'],
#     [77, 84, 'AGE'],
#     [218, 278, 'WORKCONDITIONS'],
#     [280, 290, 'SALARY'],
#     [193, 216, 'VACANCY'],
#     [1496, 1516, 'SKILLS'],
#     [1215, 1227, 'ORG'],
#     [1156, 1168, 'WORKFROM'],
#     [1171, 1180, 'WORKTO'],
#     [1193, 1213, 'POSITION'],
#     [1294, 1340, 'SUMMARY'],
#     [1355, 1386, 'EDUCATION'],
#     [1388, 1392, 'YEAROFGRAD'],
#     [1440, 1451, 'SPEC'],
#     [1394, 1423, 'INTER']]}],
#  ['Елизавета Ивановна Подлевских. Контакты: uranite1980@mail.ru, +7(916)1492786\r\n40 лет (родился 06 октября 1981), высшее образование\r\nМосква\r\nГражданство: Россия\r\nСистемный администратор\r\nПолная занятость, не готов к\xa0командировкам\r\n100\xa0000\xa0руб.\r\nОпыт работы 21 год\xa0и\xa02 месяца\r\nМарт\xa02016 – ноябрь\xa02021\r\n5 лет\xa0и\xa09 месяцев\r\nВедущий системный администратор (единственным IT-специалистом в организации)\r\nООО «ГИНЗБУРГ АРХИТЕКТС», Москва\r\nОбязанности:\r\n\uf0a7 Проектирование, обслуживание, монтаж, модернизация и расширение локальной вычислительной сети, в том числе переезд в новое здание\r\n\uf0a7 администрирование локальной сети под управлением MS Windows 2003/2008/2012 Server, Active Directory\r\n\uf0a7 пользователи: учетные записи, политики, почта, обеспечение информационной безопасности предприятия, поддержка и обучение персонала\r\n\uf0a7 оперативный перевод пользователей на режим удаленной работы на базе KERIO,\r\n\uf0a7 администрирование систем хранения и резервирования данных – freeNAS, Synology,\r\n\uf0a7 обслуживание СКУД LEGOS\r\n\uf0a7 сборка, настройка, модернизация и ремонт компьютеров и серверов, периферийной и печатной техники, в том числе специализированной широкоформатной\r\n\uf0a7 закупка комплектующих и периферии, расходных материалов, контроль бюджета\r\n\uf0a7 обслуживание, монтаж, ремонт, взаимодействие с подрядчиками и поставщиками различных видов сетей: проводные, оптические, беспроводные, в том числе сотовые\r\n\uf0a7 обслуживание офисной АТС Panasonic TDA-200: создание пользователей, групп, стратегий звонков, переадресаций и перехватов вызовов, подключение новых абонентов\r\n\uf0a7 IP-администрирование видеонаблюдения Hikvision, Ezvis\r\n\uf0a7 аудит и решение вопросов покупки и лицензирования ПО, сопровождение договоров на покупку: операционные системы, офисное ПО, архитектурное ПО, конструкторское ПО, антивирусное ПО, и т. д., расчет и оптимизация стоимости, прогнозирование изменения потребности ресурсов при масштабировании корпоративной сети.\r\n\uf0a7 BIM (Building Information Modeling) – Администрирование и обслуживание: Серверы (ArchiCad, REVIT) САПР ПО.\r\n\uf0a7 Стройконсультант, СМЕТА.РУ, ING+ − обновление разделов и актуализация баз сетевых и локальных версий, индексов, нормативов и видов цен, резервные копии\r\n\uf0a7 Выбор решения для реализации "бесшовного" Wi-Fi для предприятия, разработка базовых конфигураций, разработка регламента и контроль.\r\n\uf0a7 Ведение технической документации, учет обслуживаемого оборудования и установленного ПО\r\n\uf0a7 Выполнение профилактических и регламентных работ по обслуживанию оборудования корпоративной сети. Настройка и обслуживание планов резервного копирования данных.\r\nСентябрь\xa02009 – сентябрь\xa02015\r\n6 лет\xa0и\xa01 месяц\r\nСистемный администратор (в единственном лице)\r\nЗАО «БАЛТИЙСКАЯ СТРОИТЕЛЬНАЯ КОМПАНИЯ (М)», Москва\r\nОбязанности:\r\n\uf0a7 разработка, обслуживание, модернизация и расширение локальной вычислительной сети\r\n\uf0a7 администрирование локальной сети под управлением MS Windows 2003/2008 Server, AD\r\n\uf0a7 пользователи: учетные записи, политики, почта, обеспечение информационной безопасности предприятия, поддержка и обучение персонала\r\n\uf0a7 сборка, настройка, модернизация и ремонт компьютеров и серверов, периферийной и печатной техники, в т. ч. специализированной широкоформатной\r\n\uf0a7 закупка комплектующих и периферии, расходных материалов\r\n\uf0a7 прокладка слаботочных и электрических систем: кабелей, монтаж коробов, распределительных коробок и патч-панелей, локальный монтаж электрики (кабели, розетки)\r\n\uf0a7 обслуживание, монтаж, ремонт, взаимодействие с представителями различных видов сетей: проводные, оптические, беспроводные, в том числе сотовые.\r\n\uf0a7 обслуживание офисной АТС на базе ОС FreePBX (Asterisk) – осуществлен успешный переход на IP-телефонию со старой АТС Siemens Hicom 150, создание пользователей, групп, стратегий звонков, переадресаций и пере ...
#   {'entities': [[0, 29, 'NAME'],
#     [62, 76, 'PHONE'],
#     [132, 138, 'CITY'],
#     [41, 60, 'EMAIL'],
#     [256, 273, 'WOEXP'],
#     [78, 84, 'AGE'],
#     [186, 228, 'WORKCONDITIONS'],
#     [230, 241, 'SALARY'],
#     [161, 184, 'VACANCY'],
#     [7368, 7397, 'LANG'],
#     [7130, 7346, 'SKILLS'],
#     [397, 429, 'ORG'],
#     [275, 284, 'WORKFROM'],
#     [287, 298, 'WORKTO'],
#     [319, 395, 'POSITION'],
#     [447, 2565, 'SUMMARY'],
#     [2662, 2712, 'ORG'],
#     [2567, 2580, 'WORKFROM'],
#     [2583, 2596, 'WORKTO'],
#     [2615, 2638, 'POSITION'],
#     [2730, 4969, 'SUMMARY'],
#     [5086, 5136, 'ORG'],
#     [4971, 4980, 'WORKFROM'],
#     [4983, 4996, 'WORKTO'],
#     [5016, 5039, 'POSITION'],
#     [5154, 5745, 'SUMMARY'],
#     [5832, 5915, 'ORG'],
#     [5747, 5758, 'WORKFROM'],
#     [5761, 5773, 'WORKTO'],
#     [5786, 5830, 'POSITION'],
#     [5933, 6313, 'SUMMARY'],
#     [6398, 6461, 'ORG'],
#     [6316, 6324, 'WORKFROM'],
#     [6327, 6338, 'WORKTO'],
#     [6360, 6396, 'POSITION'],
#     [6478, 6784, 'SUMMARY'],
#     [6799, 6817, 'EDUCATION'],
#     [6834, 6838, 'YEAROFGRAD'],
#     [6979, 7085, 'SPEC'],
#     [6840, 6889, 'INTER']]}],
#  ['Вячеслав Антонович Перешнев. Контакты: grunting2036@gmail.com, +7(983)1601046\r\n39 лет (родился 07 ноября 1982), высшее образование, cостоит в браке, есть дети\r\nМосква\r\nГражданство: Россия\r\nАдминистратор сайта\r\nПолная занятость, удаленная работа, готов к\xa0командировкам\r\n30\xa0000\xa0руб.\r\nОпыт работы 13 лет\xa0и\xa08 месяцев\r\nОктябрь\xa02018 – август\xa02019\r\n11 месяцев\r\nИнтернет-маркетолог\r\nООО «Альфа Металл Групп», Москва\r\nhttp://metalfa.ru\r\nМеталлопрокат и металлоконструкции\r\nОбязанности:\r\nСоздание и ведение сайта на CMS Modx\r\nНастройка и интеграция битрикс24\r\nПеревод всех сотрудников на работу в битикс24\r\nНастройка рекламных кампаний на всех площадках: директ, adwords, facebook, inst, авито, suplbiz... более 30 площадок\r\nПодключение и настройка телефонии: мегафон, задарма.\r\nEmail рассылки, в том числе триггерные рассылки\r\nSMS рассылки\r\nСоздание сайтов под определенные задачи\r\nДостижения:\r\nСтоимость лида составляла 150 рублей.\r\nАвгуст\xa02017 – октябрь\xa02018\r\n1 год\xa0и\xa03 месяца\r\nИнтернет-маркетолог\r\nСтальтрубосервис, Москва\r\nhttp://Стальтрубосервис.рф\r\nМеталлопрокат\r\nОбязанности:\r\nСоздание сайта с нуля. Составление маркетинг плана. Привлечение лидов со всех каналов трафика: Директ, Adwords, доски объявлений, строительные порталы, авито, tiu.ru, metaprom, supl.biz... около 40 площадок. Четко выстроенная работа. Настройка сквозной аналитики - comagic. Сайт - Modx Revo. Есть рекомендательное письмо. Перед закрытием компании стоимость лида составляла 150 рублей.\r\nДостижения:\r\nУвеличение отдела продаж до 20 сотрудников, за счет увеличения кол-ва заявок в компанию.\r\nФевраль\xa02016 – август\xa02017\r\n1 год\xa0и\xa07 месяцев\r\nИнтернет-маркетолог\r\nПохудайБаттл\r\nhttp://pbattle.ru\r\nПроект для желающих похудеть\r\nОбязанности:\r\nПроект для желающих похудеть.\r\nПолный контроль работы над проектом:\r\nсоставление методического материала\r\nконтроль работы разработчиков\r\nнабор персонала\r\nсоставление и запуск рекламных кампаний\r\nсоставление ТЗ\r\nпостановка задач персоналу и контроль их выполнения\r\nвстречи с партнерами.....\r\nИюнь\xa02014 – июнь\xa02016\r\n2 года\xa0и\xa01 месяц\r\nИнтернет-маркетолог\r\nСанкт-Петербургское государственное унитарное предприятие “Санкт-Петербургский” информационно аналитический центр, Москва\r\nhttp://www.iac.spb.ru\r\nОбязанности:\r\nКонтроль работы IT отдела. Создание и продвижение сайтов с нуля. Ежедневная, монотонная работа по повышению позиций по ключевым словам в поисковых системах. Сбор семантического ядра. Кластеризация. Распределение по коммерческим и информационным запросам. Еженедельные отчеты о проделанной работе и результатах.\r\nЯнварь\xa02011 – октябрь\xa02014\r\n3 года\xa0и\xa010 месяцев\r\nИнтернет-маркетолог\r\nАгенство интернет-маркетинга Multitop, Москва\r\nhttp://multitop.ru\r\nИнформационные технологии, системная интеграция, интернетИнтернет-компания (поисковики, платежные системы, соц. сети, информационно-познавательные и развлекательные ресурсы, продвижение сайтов и прочее)\r\nОбязанности:\r\nСоздание сайтов с нуля на CMS: MODx (evolution, revolution), Bitrix, WP, Joomla, OpenCart и другие. Настройка сквозной аналитики. Связки: Битрикс24, AmorCrm - Ройстат, comagic. Написано много различных парсеров - сбор контактных данных из яндекс справочника и поисковой выдачи с последующей настройкой рекламных кампаний в Директ, Adwords, Facebook, VK...\r\nEmail маркетинг, SEO и многое другое.\r\nДоходило до ведения 25 проектов одновременно.\r\nЯнварь\xa02006 – апрель\xa02011\r\n5 лет\xa0и\xa04 месяца\r\nИнтернет-маркетолог\r\nПродвижение сайтов\r\nhttp://prodvizheniyesaytov.ru\r\nИнформационные технологии, системная интеграция, интернетИнтернет-компания (поисковики, платежные системы, соц. сети, информационно-познавательные и развлекательные ресурсы, продвижение сайтов и прочее)\r\nОбязанности:\r\nЛидогенерация. Поиск новых площадок для привлечения целевого трафика. Создание сайтов для клиентов  ...
#   {'entities': [[0, 27, 'NAME'],
#     [63, 77, 'PHONE'],
#     [160, 166, 'CITY'],
#     [39, 61, 'EMAIL'],
#     [294, 312, 'WOEXP'],
#     [375, 407, 'ORG'],
#     [314, 326, 'WORKFROM'],
#     [329, 340, 'WORKTO'],
#     [354, 373, 'POSITION'],
#     [478, 514, 'SUMMARY'],
#     [516, 548, 'SUMMARY'],
#     [550, 595, 'SUMMARY'],
#     [597, 713, 'SUMMARY'],
#     [715, 766, 'SUMMARY'],
#     [769, 816, 'SUMMARY'],
#     [818, 830, 'SUMMARY'],
#     [832, 871, 'SUMMARY'],
#     [886, 922, 'ACHIEVEMENTS'],
#     [79, 85, 'AGE'],
#     [210, 267, 'WORKCONDITIONS'],
#     [269, 279, 'SALARY'],
#     [189, 208, 'VACANCY'],
#     [4551, 4576, 'LANG'],
#     [4440, 4530, 'SKILLS'],
#     [3830, 3848, 'EDUCATION'],
#     [3864, 3868, 'YEAROFGRAD'],
#     [4034, 4054, 'SPEC'],
#     [3870, 3921, 'INTER'],
#     [4056, 4074, 'EDUCATION'],
#     [4097, 4164, 'INTER'],
#     [4091, 4095, 'YEAROFGRAD'],
#     [4195, 4231, 'SPEC'],
#     [4233, 4264, 'EDUCATION'],
#     [4287, 4344, 'INTER'],
#     [4281, 4285, 'YEAROFGRAD'],
#     [4372, 4395, 'ORG'],
#     [992, 1016, 'ORG'],
#     [925, 936, 'WORKFROM'],
#     [939, 951, 'WORKTO'],
#     [971, 990, 'POSITION'],
#     [1075, 1458, 'SUMMARY'],
#     [1474, 1561, 'ACHIEVEMENTS'],
#     [1564, 1576, 'WORKFROM'],
#     [1579, 1590, 'WORKTO'],
#     [1632, 1644, 'ORG'],
#     [1611, 1630, 'POSITION'],
#     [1709, 1998, 'SUMMARY'],
#     [2000, 2009, 'WORKFROM'],
#     [2012, 2021, 'WORKTO'],
#     [2041, 2060, 'POSITION'],
#     [2062, 2183, 'ORG'],
#     [2222, 2531, 'SUMMARY'],
#     [2534, 2545, 'WORKFROM'],
#     [2548, 2560, 'WORKTO'],
#     [2583, 2602, 'POSITION'],
#     [2604, 2649, 'ORG'],
#     [3667, 3814, 'SUMMARY'],
#     [2889, 3244, 'SUMMARY'],
#     [3246, 3282, 'SUMMARY'],
#     [3285, 3329, 'SUMMARY'],
#     [3332, 3343, 'WORKFROM'],
#     [3346, 3357, 'WORKTO'],
#     [3377, 3396, 'POSITION'],
#     [3398, 3416, 'ORG']]}],
#  ['Владислав Яковлевич Грубрин. Контакты: benefactory1844@list.ru, +7(985)9266997\r\n26 лет (родился 30 мая 1995), среднее образование\r\nМосква, \r\nМарьина роща\r\nГражданство: Россия\r\nСистемный администратор\r\nПолная занятость, не готов к\xa0командировкам\r\n50\xa0000\xa0руб.\r\nОпыт работы 7 лет\xa0и\xa04 месяца\r\nЯнварь\xa02015 – работает\xa0сейчас\r\n7 лет\xa0и\xa04 месяца\r\nСборщик ПК\r\nИндивидуальное предпринимательство / частная практика / фриланс\r\nОбязанности:\r\nСборка и обслуживание ПК, переустановка или обновление операционной системы, драйверов и БИОС, установка двойной загрузки ОС, первичная настройка\r\nОбразование\r\nСреднее образование\r\nЗнания и навыки\r\nПрофессиональные навыки:\r\nОС Windows, Linux, Настройка ПК, Настройка ПО, Сборка ПК, Ремонт ПК, Английский язык, Работа с оргтехникой, Управление VDS/VPS, Пользователь ПК\r\nДополнительные сведения:\r\nУстановка и настройка ОС Windows, Linux\r\nУстановка, обновление, удаление драйверов устройств и комплектующих.\r\nЗамена картриджей.\r\nОпыт в управлении, настройки VDS/VPS\r\nОпыт работы в помощи с оборудованием на АО Почта России, помогал коллегам.\r\nОпыт сборки компьютеров с нуля, а так же их модернизация.\r\nИностранные языки\r\nАнглийский язык — базовый',
#   {'entities': [[0, 27, 'NAME'],
#     [64, 78, 'PHONE'],
#     [131, 137, 'CITY'],
#     [39, 62, 'EMAIL'],
#     [270, 286, 'WOEXP'],
#     [349, 412, 'ORG'],
#     [288, 299, 'WORKFROM'],
#     [302, 317, 'WORKTO'],
#     [337, 347, 'POSITION'],
#     [428, 573, 'SUMMARY'],
#     [588, 607, 'EDUCATION'],
#     [652, 795, 'SKILLS'],
#     [823, 862, 'SKILLS'],
#     [954, 990, 'SKILLS'],
#     [864, 931, 'SKILLS'],
#     [934, 951, 'SKILLS'],
#     [1146, 1171, 'LANG'],
#     [176, 199, 'VACANCY'],
#     [245, 255, 'SALARY'],
#     [201, 243, 'WORKCONDITIONS'],
#     [80, 86, 'AGE'],
#     [992, 1065, 'SUMMARY'],
#     [1068, 1124, 'SUMMARY']]}]]

# %%
ner=nlp.get_pipe("ner")

# %%
for _, annotations in train_data:
    for ent in annotations.get("entities"):
        ner.add_label(ent[2])

# %%
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
import random
from spacy.util import minibatch, compounding
from pathlib import Path
from spacy.training.example import Example

# %%
# TRAINING THE MODEL
with nlp.disable_pipes(*unaffected_pipes):

  # Training for 30 iterations
  for iteration in range(30):

    # shuufling examples  before every iteration
    random.shuffle(train_data)
    losses = {}
    # batch up the examples using spaCy's minibatch
    batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        texts, annotations = zip(*batch)
        example = []
        for i in range(len(texts)):
            doc = nlp.make_doc(texts[i])
            example.append(Example.from_dict(doc, annotations[i]))
        #texts, annotations = zip(*batch)
        nlp.update(
                    example,  # batch of annotations
                    drop=0.5,  # dropout - make it harder to memorise data
                    losses=losses,
                )
        print("Losses", losses)
# Out:
# Losses {'ner': 3218.250312805176}
# Losses {'ner': 7089.293720245361}
# Losses {'ner': 8624.941919326782}
# Losses {'ner': 10744.571216583252}
# Losses {'ner': 11727.251591682434}
# Losses {'ner': 12829.770524024963}
# Losses {'ner': 13688.269588470459}
# Losses {'ner': 14769.58487701416}
# Losses {'ner': 15913.85788345337}
# Losses {'ner': 17693.154096603394}
# Losses {'ner': 19157.011703252792}
# Losses {'ner': 21615.217555761337}
# Losses {'ner': 22548.307270407677}
# Losses {'ner': 23074.659220576286}
# Losses {'ner': 24597.51749098301}
# Losses {'ner': 25182.401116788387}
# Losses {'ner': 25641.843541890383}
# Losses {'ner': 26115.759645074606}
# Losses {'ner': 27416.579252809286}
# Losses {'ner': 28315.147343724966}
# Losses {'ner': 28824.8074541986}
# Losses {'ner': 30857.846772283316}
# Losses {'ner': 32129.86129102111}
# Losses {'ner': 33354.98511657119}
# Losses {'ner': 34487.93730315566}
# Losses {'ner': 36626.152532190084}
# Losses {'ner': 37530.020528405905}
# Losses {'ner': 39696.71883830428}
# Losses {'ner': 40996.170534700155}
# Losses {'ner': 41792.361828416586}
# Losses {'ner': 42343.33294439316}
# Losses {'ner': 43000.680534780025}
# Losses {'ner': 44388.37357801199}
# Losses {'ner': 44823.93667379022}
# Losses {'ner': 46168.83881726861}
# Losses {'ner': 47281.92468801141}
# Losses {'ner': 48716.32821050286}
# Losses {'ner': 49424.35114791989}
# Losses {'ner': 50724.15275028348}
# Losses {'ner': 51845.56780079007}
# Losses {'ner': 648.1381373405457}
# Losses {'ner': 1370.2255935668945}
# Losses {'ner': 2428.3448486328125}
# Losses {'ner': 4164.078521728516}
# Losses {'ner': 6069.930114746094}
# Losses {'ner': 7153.453342437744}
# Losses {'ner': 7641.392876684666}
# Losses {'ner': 8854.014871180058}
# Losses {'ner': 9678.175029933453}
# Losses {'ner': 10059.57957020402}
# Losses {'ner': 10634.867208868265}
# Losses {'ner': 12378.778542906046}
# Losses {'ner': 13129.396023899317}
# Losses {'ner': 13947.903331190348}
# Losses {'ner': 14887.849214464426}
# Losses {'ner': 16129.65154543519}
# Losses {'ner': 17524.683591753244}
# Losses {'ner': 18880.70987930894}
# Losses {'ner': 19199.203629229218}
# Losses {'ner': 19913.753430578858}
# Losses {'ner': 21410.210399840027}
# Losses {'ner': 22327.626639101654}
# Losses {'ner': 23224.113959047943}
# Losses {'ner': 23759.30021259561}
# Losses {'ner': 24949.137696955353}
# Losses {'ner': 26583.87092993036}
# Losses {'ner': 27218.844308707863}
# Losses {'ner': 28199.389416787773}
# Losses {'ner': 28782.81812486425}
# Losses {'ner': 30826.19626626745}
# Losses {'ner': 32158.067103479058}
# Losses {'ner': 33091.07781276479}
# Losses {'ner': 33460.63391113654}
# Losses {'ner': 34510.95095014945}
# Losses {'ner': 35302.105571273714}
# Losses {'ner': 36790.40607023612}
# Losses {'ner': 38577.61797476187}
# Losses {'ner': 39010.86011973396}
# Losses {'ner': 40979.290398512036}
# Losses {'ner': 42432.765518102795}
# Losses {'ner': 1557.3640179634094}
# Losses {'ner': 1931.8152104765177}
# Losses {'ner': 2531.7923661619425}
# Losses {'ner': 3260.9629966169596}
# Losses {'ner': 5132.621989384294}
# Losses {'ner': 6942.377299442887}
# Losses {'ner': 7782.403660431504}
# Losses {'ner': 8811.771170988679}
# Losses {'ner': 10210.709402933717}
# Losses {'ner': 11118.713717356324}
# Losses {'ner': 12351.174605742097}
# Losses {'ner': 13977.819134131074}
# Losses {'ner': 14880.5734321028}
# Losses {'ner': 15889.584380760789}
# Losses {'ner': 16543.116419687867}
# Losses {'ner': 17187.419483080506}
# Losses {'ner': 18090.53008927405}
# Losses {'ner': 20271.977411165833}
# Losses {'ner': 20840.17146588862}
# Losses {'ner': 21908.535182014108}
# Losses {'ner': 23416.392179504037}
# Losses {'ner': 24450.57086159289}
# Losses {'ner': 24700.094909651787}
# Losses {'ner': 25536.908703310997}
# Losses {'ner': 26393.176587088616}
# Losses {'ner': 26831.485056503327}
# Losses {'ner': 27480.161491437466}
# Losses {'ner': 27635.76534885791}
# Losses {'ner': 27837.36882467942}
# Losses {'ner': 28238.985411060057}
# Losses {'ner': 28966.880415570937}
# Losses {'ner': 30113.668709409438}
# Losses {'ner': 30487.190756750308}
# Losses {'ner': 30602.33301318357}
# Losses {'ner': 32417.958832389806}
# Losses {'ner': 33863.10683263013}
# Losses {'ner': 34802.28979528615}
# Losses {'ner': 36071.23829687307}
# Losses {'ner': 36733.887108690236}
# Losses {'ner': 37249.644003636335}
# Losses {'ner': 629.8416768312454}
# Losses {'ner': 1310.5657277107239}
# Losses {'ner': 2401.2998538017273}
# Losses {'ner': 3673.782220363617}
# Losses {'ner': 4273.250118255615}
# Losses {'ner': 5602.117942810059}
# Losses {'ner': 7037.916816711426}
# Losses {'ner': 7585.773943245411}
# Losses {'ner': 8895.583007156849}
# Losses {'ner': 9560.688847124577}
# Losses {'ner': 11283.498407900333}
# Losses {'ner': 12258.512295782566}
# Losses {'ner': 13158.754333555698}
# Losses {'ner': 13965.647220671177}
# Losses {'ner': 14356.121097147465}
# Losses {'ner': 15028.83252722025}
# Losses {'ner': 15808.877373993397}
# Losses {'ner': 16184.956708967686}
# Losses {'ner': 16725.62242537737}
# Losses {'ner': 17286.117573320866}
# Losses {'ner': 17720.295453369617}
# Losses {'ner': 18769.7031558156}
# Losses {'ner': 19001.188796438277}
# Losses {'ner': 19548.52466598898}
# Losses {'ner': 20393.077919878066}
# Losses {'ner': 21396.73656836897}
# Losses {'ner': 22422.100533880293}
# Losses {'ner': 23231.899499334395}
# Losses {'ner': 23815.494825042784}
# Losses {'ner': 24470.886288799345}
# Losses {'ner': 24868.764480459737}
# Losses {'ner': 25878.768313515233}
# Losses {'ner': 26505.212214934872}
# Losses {'ner': 27734.339952456998}
# Losses {'ner': 28285.065574395703}
# Losses {'ner': 29343.87722753291}
# Losses {'ner': 29858.07174758031}
# Losses {'ner': 30223.676234820625}
# Losses {'ner': 31426.006855109474}
# Losses {'ner': 32263.838782408973}
# Losses {'ner': 707.8026111572981}
# Losses {'ner': 1075.9724825024605}
# Losses {'ner': 2454.8887031674385}
# Losses {'ner': 3234.0593240857124}
# Losses {'ner': 4251.3774741292}
# Losses {'ner': 4977.400176346302}
# Losses {'ner': 5668.71309286356}
# Losses {'ner': 6000.031767785549}
# Losses {'ner': 6207.910398523214}
# Losses {'ner': 6687.594601730707}
# Losses {'ner': 7335.830919365289}
# Losses {'ner': 7620.884294598254}
# Losses {'ner': 8370.761314480456}
# Losses {'ner': 9482.640450565967}
# Losses {'ner': 10072.142682163867}
# Losses {'ner': 10633.269468157443}
# Losses {'ner': 11168.42444834009}
# Losses {'ner': 11948.900672404918}
# Losses {'ner': 12544.735100119266}
# Losses {'ner': 13105.371723501834}
# Losses {'ner': 13686.493388025912}
# Losses {'ner': 14342.546717970523}
# Losses {'ner': 15021.745190947207}
# Losses {'ner': 16002.527956335696}
# Losses {'ner': 16712.74339184061}
# Losses {'ner': 17412.4075799872}
# Losses {'ner': 17674.457843101474}
# Losses {'ner': 18551.026830113384}
# Losses {'ner': 19498.734879410717}
# Losses {'ner': 20198.82819072053}
# Losses {'ner': 20885.903403437587}
# Losses {'ner': 21196.958105976526}
# Losses {'ner': 21709.91609882826}
# Losses {'ner': 22265.37644755358}
# Losses {'ner': 22640.52255695576}
# Losses {'ner': 23449.2917320084}
# Losses {'ner': 23939.478972515855}
# Losses {'ner': 24901.359646878038}
# Losses {'ner': 25467.778172871862}
# Losses {'ner': 25825.118551742235}
# Losses {'ner': 353.474249958992}
# Losses {'ner': 690.880488306284}
# Losses {'ner': 1126.0131975859404}
# Losses {'ner': 1397.2453387603164}
# Losses {'ner': 2068.7739041671157}
# Losses {'ner': 2568.94141045399}
# Losses {'ner': 3011.8682945091277}
# Losses {'ner': 3815.4374262411147}
# Losses {'ner': 4045.8215001029894}
# Losses {'ner': 4872.2435747412965}
# Losses {'ner': 5545.37940359395}
# Losses {'ner': 5963.072278144769}
# Losses {'ner': 6684.78727782052}
# Losses {'ner': 7086.277276094304}
# Losses {'ner': 7621.760368476855}
# Losses {'ner': 7919.818584184395}
# Losses {'ner': 8517.11261361395}
# Losses {'ner': 9032.973662297474}
# Losses {'ner': 9350.395994256483}
# Losses {'ner': 10025.475580941187}
# Losses {'ner': 10845.394802819239}
# Losses {'ner': 11165.885583604919}
# Losses {'ner': 11665.908002640354}
# Losses {'ner': 12294.54049852048}
# Losses {'ner': 12694.571671988117}
# Losses {'ner': 12921.608404721366}
# Losses {'ner': 13379.46607610141}
# Losses {'ner': 13638.427958389511}
# Losses {'ner': 13882.841485058656}
# Losses {'ner': 14083.915992584429}
# Losses {'ner': 14550.175736826262}
# Losses {'ner': 15399.20925418695}
# Losses {'ner': 15772.140515620005}
# Losses {'ner': 17202.80372172047}
# Losses {'ner': 17875.10193722893}
# Losses {'ner': 18658.493127280963}
# Losses {'ner': 19282.45137351204}
# Losses {'ner': 19929.473360234988}
# Losses {'ner': 20345.431811267626}
# Losses {'ner': 20555.36168001846}
# Losses {'ner': 321.8066412881017}
# Losses {'ner': 757.4897506795824}
# Losses {'ner': 1511.2980788312852}
# Losses {'ner': 1742.3586085715215}
# Losses {'ner': 2025.680719582073}
# Losses {'ner': 2459.305487177742}
# Losses {'ner': 3600.215573809517}
# Losses {'ner': 4099.139460466278}
# Losses {'ner': 4997.540739915741}
# Losses {'ner': 5620.142930291069}
# Losses {'ner': 5962.606540344132}
# Losses {'ner': 6658.635159395111}
# Losses {'ner': 6959.075091004837}
# Losses {'ner': 7800.372347474564}
# Losses {'ner': 8040.007662034128}
# Losses {'ner': 8663.199442191515}
# Losses {'ner': 8988.918566359673}
# Losses {'ner': 9368.263694061432}
# Losses {'ner': 9802.291948928032}
# Losses {'ner': 10323.004042162094}
# Losses {'ner': 11020.560672892723}
# Losses {'ner': 11310.422246853355}
# Losses {'ner': 11534.095373840537}
# Losses {'ner': 11873.175362856593}
# Losses {'ner': 12035.954488930758}
# Losses {'ner': 12626.95911806589}
# Losses {'ner': 12931.535844692495}
# Losses {'ner': 13353.700456046965}
# Losses {'ner': 13795.653554180171}
# Losses {'ner': 14254.229251840618}
# Losses {'ner': 14608.525033109123}
# Losses {'ner': 14796.982315507485}
# Losses {'ner': 14993.499604881508}
# Losses {'ner': 15360.760127962334}
# Losses {'ner': 15529.437401638133}
# Losses {'ner': 16124.495230630739}
# Losses {'ner': 16694.31829676847}
# Losses {'ner': 16897.275774670532}
# Losses {'ner': 17371.73214746802}
# Losses {'ner': 17769.85711397021}
# Losses {'ner': 390.39629412069917}
# Losses {'ner': 627.10212308052}
# Losses {'ner': 1119.296355253784}
# Losses {'ner': 1560.9802807650995}
# Losses {'ner': 1813.4383875583299}
# Losses {'ner': 2369.661201499868}
# Losses {'ner': 2772.274549552705}
# Losses {'ner': 3465.3725023022853}
# Losses {'ner': 4174.117394065019}
# Losses {'ner': 4462.300589268561}
# Losses {'ner': 5074.972913329955}
# Losses {'ner': 5303.612113689538}
# Losses {'ner': 5752.396596407052}
# Losses {'ner': 5989.717236104887}
# Losses {'ner': 6499.52130228607}
# Losses {'ner': 7356.500963959377}
# Losses {'ner': 7518.679663642863}
# Losses {'ner': 7915.245678647974}
# Losses {'ner': 8207.429926022509}
# Losses {'ner': 8445.635723462416}
# Losses {'ner': 8752.635881057096}
# Losses {'ner': 9092.898938207043}
# Losses {'ner': 9384.677290482534}
# Losses {'ner': 9643.463478012098}
# Losses {'ner': 10020.026070514316}
# Losses {'ner': 10401.039918804163}
# Losses {'ner': 10651.157996447379}
# Losses {'ner': 10977.213839964563}
# Losses {'ner': 11108.68454793912}
# Losses {'ner': 11488.576298036394}
# Losses {'ner': 11740.555455681853}
# Losses {'ner': 12070.918198530548}
# Losses {'ner': 12491.073272620313}
# Losses {'ner': 12901.34697612327}
# Losses {'ner': 13128.14832612079}
# Losses {'ner': 13529.017386100706}
# Losses {'ner': 13774.990460610265}
# Losses {'ner': 14382.972766832696}
# Losses {'ner': 14807.376251534806}
# Losses {'ner': 15093.173964129077}
# Losses {'ner': 275.6838280701195}
# Losses {'ner': 532.2604838184197}
# Losses {'ner': 764.9365003132843}
# Losses {'ner': 1223.6362560862326}
# Losses {'ner': 1517.040016459825}
# Losses {'ner': 1837.1421560852905}
# Losses {'ner': 1984.740040401366}
# Losses {'ner': 2314.2371070779827}
# Losses {'ner': 2628.6755387767826}
# Losses {'ner': 2924.5282898399655}
# Losses {'ner': 3110.8805151912147}
# Losses {'ner': 3636.4393483432705}
# Losses {'ner': 4087.8772206040794}
# Losses {'ner': 4360.500463123293}
# Losses {'ner': 4591.81998621379}
# Losses {'ner': 4888.193796926038}
# Losses {'ner': 5157.37499254276}
# Losses {'ner': 5321.228020440647}
# Losses {'ner': 5564.4135303384155}
# Losses {'ner': 6143.836217153677}
# Losses {'ner': 6747.24091290296}
# Losses {'ner': 7024.919215876469}
# Losses {'ner': 7446.916584495315}
# Losses {'ner': 8050.918410781631}
# Losses {'ner': 8544.237503293762}
# Losses {'ner': 8992.205713037261}
# Losses {'ner': 9270.798932763608}
# Losses {'ner': 9631.575714412005}
# Losses {'ner': 10042.074612988492}
# Losses {'ner': 10366.544133378526}
# Losses {'ner': 10953.0822228327}
# Losses {'ner': 11634.761554850598}
# Losses {'ner': 12119.111950470467}
# Losses {'ner': 12531.12610192444}
# Losses {'ner': 12971.458363546391}
# Losses {'ner': 13083.46253716752}
# Losses {'ner': 13243.799994073734}
# Losses {'ner': 14048.733819566593}
# Losses {'ner': 14333.39373756146}
# Losses {'ner': 14706.907244927641}
# Losses {'ner': 181.24275635178492}
# Losses {'ner': 398.62314276730467}
# Losses {'ner': 1048.041937339658}
# Losses {'ner': 1371.4487203905155}
# Losses {'ner': 2173.9942251989414}
# Losses {'ner': 2328.1015010358096}
# Losses {'ner': 2701.0358243466617}
# Losses {'ner': 2871.2188072980643}
# Losses {'ner': 3266.726477486387}
# Losses {'ner': 3390.248146645099}
# Losses {'ner': 3531.227751792714}
# Losses {'ner': 3974.4226460469217}
# Losses {'ner': 4283.86744073157}
# Losses {'ner': 4671.19791987662}
# Losses {'ner': 5339.029405386493}
# Losses {'ner': 5570.065781094439}
# Losses {'ner': 5952.117852188952}
# Losses {'ner': 6159.525623677109}
# Losses {'ner': 6628.0978012185515}
# Losses {'ner': 7078.821824199331}
# Losses {'ner': 7662.63756955303}
# Losses {'ner': 7911.5570961300255}
# Losses {'ner': 8194.335096365583}
# Losses {'ner': 8549.805864253824}
# Losses {'ner': 8940.292495498245}
# Losses {'ner': 9086.575070079725}
# Losses {'ner': 9349.82272323393}
# Losses {'ner': 9474.920586816914}
# Losses {'ner': 9740.855554424174}
# Losses {'ner': 9983.676919508323}
# Losses {'ner': 10386.249854582891}
# Losses {'ner': 10785.283594373212}
# Losses {'ner': 11012.109945583687}
# Losses {'ner': 11145.044873947108}
# Losses {'ner': 11583.948713296855}
# Losses {'ner': 11865.97630438378}
# Losses {'ner': 12125.513392897154}
# Losses {'ner': 12296.450893193547}
# Losses {'ner': 12484.898070326139}
# Losses {'ner': 12893.70969938307}
# Losses {'ner': 337.7695626579225}
# Losses {'ner': 914.3886311613023}
# Losses {'ner': 1211.2599919848144}
# Losses {'ner': 1398.2798017125315}
# Losses {'ner': 1555.958081414079}
# Losses {'ner': 1825.7316540601605}
# Losses {'ner': 2103.496517193591}
# Losses {'ner': 2338.482751858508}
# Losses {'ner': 2471.6209316923196}
# Losses {'ner': 2637.0536110511894}
# Losses {'ner': 2820.4298786388827}
# Losses {'ner': 3235.2587866352987}
# Losses {'ner': 3582.819108323951}
# Losses {'ner': 3911.456198396918}
# Losses {'ner': 4654.671546640631}
# Losses {'ner': 5083.870572211978}
# Losses {'ner': 5391.776778521773}
# Losses {'ner': 5674.732386681077}
# Losses {'ner': 6312.456788631913}
# Losses {'ner': 6533.556912035507}
# Losses {'ner': 7005.029906009149}
# Losses {'ner': 7284.448691848636}
# Losses {'ner': 7435.307390610658}
# Losses {'ner': 7671.218566100133}
# Losses {'ner': 7935.94285289107}
# Losses {'ner': 8076.326362194048}
# Losses {'ner': 8205.27445282242}
# Losses {'ner': 8379.478097870035}
# Losses {'ner': 8553.477471997516}
# Losses {'ner': 8970.420710971133}
# Losses {'ner': 9164.10719567551}
# Losses {'ner': 9485.559172839063}
# Losses {'ner': 9690.241475468638}
# Losses {'ner': 10028.671819877016}
# Losses {'ner': 10300.180664729463}
# Losses {'ner': 10617.941598322379}
# Losses {'ner': 10830.817618120598}
# Losses {'ner': 11574.682334173607}
# Losses {'ner': 11904.017286885666}
# Losses {'ner': 12073.844404483758}
# Losses {'ner': 204.21366338757798}
# Losses {'ner': 331.03962121644145}
# Losses {'ner': 456.86052584574645}
# Losses {'ner': 707.5963196802986}
# Losses {'ner': 1105.35515864865}
# Losses {'ner': 1669.3740608908338}
# Losses {'ner': 2115.501964233081}
# Losses {'ner': 2580.580577991168}
# Losses {'ner': 3053.718274793784}
# Losses {'ner': 3202.299838396917}
# Losses {'ner': 3382.6946876963702}
# Losses {'ner': 3753.603308724436}
# Losses {'ner': 4053.142760889801}
# Losses {'ner': 4232.40310820398}
# Losses {'ner': 4522.639700615975}
# Losses {'ner': 4786.513305926892}
# Losses {'ner': 5030.270159908214}
# Losses {'ner': 5442.097377248683}
# Losses {'ner': 5776.624392457881}
# Losses {'ner': 5973.536160044947}
# Losses {'ner': 6428.871095888891}
# Losses {'ner': 6519.024520808232}
# Losses {'ner': 6688.444225752128}
# Losses {'ner': 6834.8618887777975}
# Losses {'ner': 7389.239692341869}
# Losses {'ner': 7556.792526144809}
# Losses {'ner': 8080.033557553119}
# Losses {'ner': 8240.987962559024}
# Losses {'ner': 8975.01974327878}
# Losses {'ner': 9155.99707146191}
# Losses {'ner': 9263.875064560982}
# Losses {'ner': 9726.376583883377}
# Losses {'ner': 9811.729186563181}
# Losses {'ner': 10475.482835797953}
# Losses {'ner': 10691.79108111317}
# Losses {'ner': 11040.529655021975}
# Losses {'ner': 11278.12144223625}
# Losses {'ner': 11591.142511792725}
# Losses {'ner': 11721.596084876695}
# Losses {'ner': 12017.568288429418}
# Losses {'ner': 125.15443658828735}
# Losses {'ner': 329.41033242613776}
# Losses {'ner': 505.4743287113379}
# Losses {'ner': 674.9630466780509}
# Losses {'ner': 816.7439173503153}
# Losses {'ner': 1350.7034992022745}
# Losses {'ner': 1693.8219734433878}
# Losses {'ner': 2158.9566853087235}
# Losses {'ner': 2681.183995608597}
# Losses {'ner': 2795.961436133897}
# Losses {'ner': 2991.451611132252}
# Losses {'ner': 3426.6102381654855}
# Losses {'ner': 3752.5335357271906}
# Losses {'ner': 4354.066683896708}
# Losses {'ner': 4458.2106226710675}
# Losses {'ner': 4921.263249042451}
# Losses {'ner': 5257.080675002195}
# Losses {'ner': 5453.939100895084}
# Losses {'ner': 5647.078398645863}
# Losses {'ner': 5859.939628985252}
# Losses {'ner': 6094.352450496059}
# Losses {'ner': 6356.970609766089}
# Losses {'ner': 6867.347305317067}
# Losses {'ner': 7095.148839304289}
# Losses {'ner': 7452.784711191496}
# Losses {'ner': 7589.050561194839}
# Losses {'ner': 7891.696838875832}
# Losses {'ner': 8048.892539334083}
# Losses {'ner': 8183.075412686339}
# Losses {'ner': 8524.370298679343}
# Losses {'ner': 9135.984645660392}
# Losses {'ner': 9376.651231582633}
# Losses {'ner': 9511.464838772554}
# Losses {'ner': 9683.226273953456}
# Losses {'ner': 10001.602098226089}
# Losses {'ner': 10197.770674847074}
# Losses {'ner': 10384.702624606209}
# Losses {'ner': 10532.593620430918}
# Losses {'ner': 10671.770479477018}
# Losses {'ner': 10832.195773755673}
# Losses {'ner': 79.46050853282213}
# Losses {'ner': 273.972741780919}
# Losses {'ner': 473.5716261813868}
# Losses {'ner': 1057.3816468665827}
# Losses {'ner': 1562.0576629588832}
# Losses {'ner': 1734.160006629907}
# Losses {'ner': 1888.4021606424576}
# Losses {'ner': 2007.7411108517772}
# Losses {'ner': 2191.2085635902113}
# Losses {'ner': 2390.0192628687}
# Losses {'ner': 2556.514994695659}
# Losses {'ner': 2852.536884054418}
# Losses {'ner': 2969.659735063171}
# Losses {'ner': 3347.3786512409206}
# Losses {'ner': 3545.588555756629}
# Losses {'ner': 3843.1120912801925}
# Losses {'ner': 4095.7730391053265}
# Losses {'ner': 4439.184163334758}
# Losses {'ner': 4637.135584176263}
# Losses {'ner': 4821.648268722674}
# Losses {'ner': 5069.11694899921}
# Losses {'ner': 5228.202677371657}
# Losses {'ner': 5524.306317812159}
# Losses {'ner': 5747.592917712733}
# Losses {'ner': 6370.870642932459}
# Losses {'ner': 6555.359022360157}
# Losses {'ner': 6649.779783215974}
# Losses {'ner': 7023.307210144256}
# Losses {'ner': 7497.527389582847}
# Losses {'ner': 7599.538440251799}
# Losses {'ner': 7817.714840540739}
# Losses {'ner': 8126.528441617342}
# Losses {'ner': 8357.133040854784}
# Losses {'ner': 8481.4551090926}
# Losses {'ner': 8677.852555238602}
# Losses {'ner': 8843.110861910467}
# Losses {'ner': 9127.737370374485}
# Losses {'ner': 9345.046682643577}
# Losses {'ner': 9464.807342174678}
# Losses {'ner': 9735.642839341872}
# Losses {'ner': 238.3536625802517}
# Losses {'ner': 584.468050390482}
# Losses {'ner': 723.7502858471271}
# Losses {'ner': 931.0132222389075}
# Losses {'ner': 1241.707872531304}
# Losses {'ner': 1393.9036735900881}
# Losses {'ner': 1658.2436567069235}
# Losses {'ner': 1803.8679278905474}
# Losses {'ner': 2010.0587391073786}
# Losses {'ner': 2186.2249977405154}
# Losses {'ner': 2405.7376846524858}
# Losses {'ner': 2546.9371435009525}
# Losses {'ner': 3021.6199719869182}
# Losses {'ner': 3161.456705639146}
# Losses {'ner': 3314.122429052375}
# Losses {'ner': 3496.092767703005}
# Losses {'ner': 3905.3931609267675}
# Losses {'ner': 4255.221600814031}
# Losses {'ner': 4412.294107454335}
# Losses {'ner': 4828.411980169331}
# Losses {'ner': 4896.722063149385}
# Losses {'ner': 5087.534517909459}
# Losses {'ner': 5244.914969354461}
# Losses {'ner': 5466.094492159377}
# Losses {'ner': 5565.971424632998}
# Losses {'ner': 5965.806003385515}
# Losses {'ner': 6094.198457246705}
# Losses {'ner': 6206.752128911264}
# Losses {'ner': 6507.669696911297}
# Losses {'ner': 6731.074840484886}
# Losses {'ner': 6845.304402145325}
# Losses {'ner': 7134.751818115591}
# Losses {'ner': 7325.160932774424}
# Losses {'ner': 7528.998551542639}
# Losses {'ner': 7684.765024546651}
# Losses {'ner': 7838.036805400742}
# Losses {'ner': 8371.452745447052}
# Losses {'ner': 8970.036780307186}
# Losses {'ner': 9081.054166374844}
# Losses {'ner': 9175.007797787679}
# Losses {'ner': 1135.9943923950195}
# Losses {'ner': 1312.6928114350885}
# Losses {'ner': 1425.45406645209}
# Losses {'ner': 1695.8668832224648}
# Losses {'ner': 1943.7971077286493}
# Losses {'ner': 2117.593664895263}
# Losses {'ner': 2227.935770118129}
# Losses {'ner': 2512.855160081279}
# Losses {'ner': 2674.5861064528}
# Losses {'ner': 2793.7048582694842}
# Losses {'ner': 2950.1789720327943}
# Losses {'ner': 3380.677269128093}
# Losses {'ner': 3835.2541109593003}
# Losses {'ner': 3944.19100599589}
# Losses {'ner': 4131.752286528077}
# Losses {'ner': 4321.9761182277725}
# Losses {'ner': 4524.708157195622}
# Losses {'ner': 4632.037236998527}
# Losses {'ner': 4818.594385600387}
# Losses {'ner': 4961.032806625513}
# Losses {'ner': 5086.64043917313}
# Losses {'ner': 5176.684907227358}
# Losses {'ner': 5700.178410917124}
# Losses {'ner': 5842.110922711148}
# Losses {'ner': 6128.385582583203}
# Losses {'ner': 6301.68247781898}
# Losses {'ner': 6559.322709446951}
# Losses {'ner': 6713.509997079327}
# Losses {'ner': 6836.573233443112}
# Losses {'ner': 7331.982643919797}
# Losses {'ner': 7699.53853567204}
# Losses {'ner': 8180.709165411801}
# Losses {'ner': 8512.045704399501}
# Losses {'ner': 8670.312074041605}
# Losses {'ner': 8814.51861580988}
# Losses {'ner': 9040.863539280574}
# Losses {'ner': 9153.965051568317}
# Losses {'ner': 9459.627454851958}
# Losses {'ner': 9617.70620362481}
# Losses {'ner': 9935.30591258427}
# Losses {'ner': 326.1266530100256}
# Losses {'ner': 469.60101077565923}
# Losses {'ner': 565.7829430915881}
# Losses {'ner': 764.7076191427186}
# Losses {'ner': 907.8499224030529}
# Losses {'ner': 1075.1535767775058}
# Losses {'ner': 1240.361400219801}
# Losses {'ner': 1348.764271762877}
# Losses {'ner': 1688.8078378743521}
# Losses {'ner': 2027.510949284493}
# Losses {'ner': 2174.8626241392485}
# Losses {'ner': 2557.4475257105223}
# Losses {'ner': 2981.520952091276}
# Losses {'ner': 3123.7638074265706}
# Losses {'ner': 3331.6345575557934}
# Losses {'ner': 3429.1879086870613}
# Losses {'ner': 3710.8993178412347}
# Losses {'ner': 3909.347916076149}
# Losses {'ner': 4052.187726345859}
# Losses {'ner': 4291.668497812949}
# Losses {'ner': 4468.64415390465}
# Losses {'ner': 4539.530729579306}
# Losses {'ner': 4678.754628936327}
# Losses {'ner': 4898.96281413225}
# Losses {'ner': 5001.185905712689}
# Losses {'ner': 5241.020595031823}
# Losses {'ner': 5872.836213725652}
# Losses {'ner': 6007.982383530981}
# Losses {'ner': 6097.74450781202}
# Losses {'ner': 6263.704723002154}
# Losses {'ner': 6763.672706248004}
# Losses {'ner': 6844.381938942961}
# Losses {'ner': 7143.669895575635}
# Losses {'ner': 7353.459417685188}
# Losses {'ner': 7722.011588973246}
# Losses {'ner': 7838.640282600498}
# Losses {'ner': 8137.023156569185}
# Losses {'ner': 8416.521639309756}
# Losses {'ner': 8520.995183649544}
# Losses {'ner': 8768.78968154553}
# Losses {'ner': 296.94186651706696}
# Losses {'ner': 426.9766304977238}
# Losses {'ner': 886.7217249013484}
# Losses {'ner': 1046.3674209937453}
# Losses {'ner': 1207.8621613229625}
# Losses {'ner': 1793.3014528001659}
# Losses {'ner': 2276.184023856651}
# Losses {'ner': 2765.015998862218}
# Losses {'ner': 3149.982722445857}
# Losses {'ner': 3473.598001475446}
# Losses {'ner': 3553.396687779663}
# Losses {'ner': 3627.69350878385}
# Losses {'ner': 3822.636863715161}
# Losses {'ner': 3955.6484270171786}
# Losses {'ner': 4155.513243939873}
# Losses {'ner': 4437.8007258224825}
# Losses {'ner': 4616.662556274707}
# Losses {'ner': 4780.8838746995025}
# Losses {'ner': 4921.104455989174}
# Losses {'ner': 5108.501255554933}
# Losses {'ner': 5270.484255093703}
# Losses {'ner': 5411.158436074475}
# Losses {'ner': 5789.173397853592}
# Losses {'ner': 5947.218849013181}
# Losses {'ner': 6039.611541004204}
# Losses {'ner': 6208.088697488558}
# Losses {'ner': 6433.674226100695}
# Losses {'ner': 6540.770554707939}
# Losses {'ner': 6735.561946050817}
# Losses {'ner': 6887.227822670742}
# Losses {'ner': 7976.797848114773}
# Losses {'ner': 8090.654708206217}
# Losses {'ner': 8160.552337389818}
# Losses {'ner': 8292.484484390676}
# Losses {'ner': 8491.72569030823}
# Losses {'ner': 8586.032046709905}
# Losses {'ner': 8648.472516768958}
# Losses {'ner': 8707.138533138084}
# Losses {'ner': 8796.887704030141}
# Losses {'ner': 9429.367051735982}
# Losses {'ner': 109.90443111211061}
# Losses {'ner': 275.58854625714594}
# Losses {'ner': 358.6447967029453}
# Losses {'ner': 573.3374426103474}
# Losses {'ner': 825.9158944543378}
# Losses {'ner': 955.5517745923062}
# Losses {'ner': 1025.489524833807}
# Losses {'ner': 1260.4499563326317}
# Losses {'ner': 1569.022420917936}
# Losses {'ner': 1812.186307483651}
# Losses {'ner': 1855.9464468044093}
# Losses {'ner': 2159.355619079804}
# Losses {'ner': 2295.397073765656}
# Losses {'ner': 2778.8503300150837}
# Losses {'ner': 2889.08303124029}
# Losses {'ner': 3052.3451854618247}
# Losses {'ner': 3237.178820881432}
# Losses {'ner': 3416.050501224024}
# Losses {'ner': 4469.288430568202}
# Losses {'ner': 4632.40614121456}
# Losses {'ner': 4775.313414060067}
# Losses {'ner': 4918.333487994234}
# Losses {'ner': 5108.944660926783}
# Losses {'ner': 5389.622851992572}
# Losses {'ner': 5513.1433410612735}
# Losses {'ner': 5570.311294299176}
# Losses {'ner': 5623.487551651659}
# Losses {'ner': 5777.718631541382}
# Losses {'ner': 5859.731972188045}
# Losses {'ner': 6076.253523264135}
# Losses {'ner': 6206.03716931125}
# Losses {'ner': 6305.048499157125}
# Losses {'ner': 6343.715496288551}
# Losses {'ner': 6494.271894011738}
# Losses {'ner': 6740.050061080697}
# Losses {'ner': 6882.154305804613}
# Losses {'ner': 6993.6213884782965}
# Losses {'ner': 7097.031705195496}
# Losses {'ner': 7202.06040811318}
# Losses {'ner': 7381.0670668050925}
# Losses {'ner': 122.35894393180206}
# Losses {'ner': 279.3813065613649}
# Losses {'ner': 360.93508401805593}
# Losses {'ner': 506.7983493674692}
# Losses {'ner': 628.5537545200277}
# Losses {'ner': 739.7000776113782}
# Losses {'ner': 799.9024991390172}
# Losses {'ner': 1060.9714428481523}
# Losses {'ner': 1165.544760784432}
# Losses {'ner': 1318.3629627939729}
# Losses {'ner': 1739.8186444709493}
# Losses {'ner': 1910.6865814993573}
# Losses {'ner': 2103.0985685730766}
# Losses {'ner': 2205.2864514407474}
# Losses {'ner': 2335.6722911675233}
# Losses {'ner': 2548.9911162192357}
# Losses {'ner': 2621.042515422253}
# Losses {'ner': 2753.6595779164118}
# Losses {'ner': 3006.462385259997}
# Losses {'ner': 3142.0456202556006}
# Losses {'ner': 3287.1565781519375}
# Losses {'ner': 3357.9622302637335}
# Losses {'ner': 4064.3044263706443}
# Losses {'ner': 4235.262940481761}
# Losses {'ner': 4789.410458043673}
# Losses {'ner': 5147.811032766932}
# Losses {'ner': 5298.26864864909}
# Losses {'ner': 5746.795275712841}
# Losses {'ner': 5981.160730982655}
# Losses {'ner': 6095.96720972889}
# Losses {'ner': 6198.8144672362005}
# Losses {'ner': 6311.8767827594465}
# Losses {'ner': 6561.664847526122}
# Losses {'ner': 6862.557692574691}
# Losses {'ner': 7048.265880363881}
# Losses {'ner': 7134.749727984778}
# Losses {'ner': 7236.774893282392}
# Losses {'ner': 7594.397416888216}
# Losses {'ner': 7674.042322280064}
# Losses {'ner': 7791.0040865449955}
# Losses {'ner': 121.09078682179097}
# Losses {'ner': 248.10360802558716}
# Losses {'ner': 455.5560207173112}
# Losses {'ner': 575.3821634917404}
# Losses {'ner': 713.97766183567}
# Losses {'ner': 1566.9418152446742}
# Losses {'ner': 1650.862243441632}
# Losses {'ner': 1742.777136361692}
# Losses {'ner': 2070.500928011557}
# Losses {'ner': 2191.5110420845244}
# Losses {'ner': 2430.043511357138}
# Losses {'ner': 2505.4915681979414}
# Losses {'ner': 2873.228166570401}
# Losses {'ner': 2961.1335841915366}
# Losses {'ner': 3107.723927599823}
# Losses {'ner': 3249.4141704563312}
# Losses {'ner': 3495.619148624342}
# Losses {'ner': 3943.0719875816517}
# Losses {'ner': 4060.379023059076}
# Losses {'ner': 4208.494140095581}
# Losses {'ner': 4361.803756698539}
# Losses {'ner': 4583.305251462889}
# Losses {'ner': 4648.360247144514}
# Losses {'ner': 4725.735282012063}
# Losses {'ner': 4815.827491539856}
# Losses {'ner': 5000.471404651447}
# Losses {'ner': 5352.589168576325}
# Losses {'ner': 5470.016925296548}
# Losses {'ner': 5565.15462774749}
# Losses {'ner': 5835.121653386033}
# Losses {'ner': 5929.703778509884}
# Losses {'ner': 6428.577709440975}
# Losses {'ner': 6530.698848628232}
# Losses {'ner': 6772.063462748916}
# Losses {'ner': 6867.257947768758}
# Losses {'ner': 6950.534753242135}
# Losses {'ner': 7266.167365856561}
# Losses {'ner': 7377.8912479110495}
# Losses {'ner': 7468.241738762843}
# Losses {'ner': 7587.287237073999}
# Losses {'ner': 277.4805405139923}
# Losses {'ner': 359.9081497663865}
# Losses {'ner': 437.26890095323324}
# Losses {'ner': 519.04423698551}
# Losses {'ner': 740.2987798131162}
# Losses {'ner': 833.9969449553264}
# Losses {'ner': 900.568924325491}
# Losses {'ner': 1180.7937191901456}
# Losses {'ner': 1702.1126051125775}
# Losses {'ner': 1785.7397816751345}
# Losses {'ner': 2075.2652337158524}
# Losses {'ner': 2198.772376568495}
# Losses {'ner': 2322.2782907833734}
# Losses {'ner': 2511.4293943702924}
# Losses {'ner': 2587.691371282328}
# Losses {'ner': 2731.686546710551}
# Losses {'ner': 2915.6099371744767}
# Losses {'ner': 3183.3190083338395}
# Losses {'ner': 3393.6957531067874}
# Losses {'ner': 3549.7445148396637}
# Losses {'ner': 3653.954650697704}
# Losses {'ner': 3729.902675566791}
# Losses {'ner': 3783.997827870193}
# Losses {'ner': 3993.1026586603875}
# Losses {'ner': 4145.813387216305}
# Losses {'ner': 4273.170901674854}
# Losses {'ner': 4376.320672763588}
# Losses {'ner': 4559.272099855549}
# Losses {'ner': 4849.378694552306}
# Losses {'ner': 5010.4903813967285}
# Losses {'ner': 5117.89056440385}
# Losses {'ner': 5258.3786238521025}
# Losses {'ner': 5433.508364405661}
# Losses {'ner': 5685.221692945986}
# Losses {'ner': 6106.479815969422}
# Losses {'ner': 6166.390446559306}
# Losses {'ner': 6441.223921433802}
# Losses {'ner': 6626.154839091714}
# Losses {'ner': 6694.698930675385}
# Losses {'ner': 6814.969597987237}
# Losses {'ner': 89.90593620971595}
# Losses {'ner': 276.918526398249}
# Losses {'ner': 692.8144170118012}
# Losses {'ner': 740.6022921267827}
# Losses {'ner': 838.2690593679285}
# Losses {'ner': 962.0187959591708}
# Losses {'ner': 1102.0796288315755}
# Losses {'ner': 1220.216866984017}
# Losses {'ner': 1335.421869318568}
# Losses {'ner': 1394.7880629052447}
# Losses {'ner': 1485.0142426764864}
# Losses {'ner': 1606.142716491238}
# Losses {'ner': 1821.924205267445}
# Losses {'ner': 1974.4596693042513}
# Losses {'ner': 2107.6271841574307}
# Losses {'ner': 2204.432517837962}
# Losses {'ner': 2409.1512305850592}
# Losses {'ner': 2527.669449230885}
# Losses {'ner': 2652.740808325685}
# Losses {'ner': 2720.051654326371}
# Losses {'ner': 2885.7998696674968}
# Losses {'ner': 3071.411300214697}
# Losses {'ner': 3568.068241151739}
# Losses {'ner': 3739.418904369688}
# Losses {'ner': 4077.8738386807872}
# Losses {'ner': 4161.9563007749875}
# Losses {'ner': 4246.477075856112}
# Losses {'ner': 4417.975275720402}
# Losses {'ner': 4536.113911148908}
# Losses {'ner': 5021.960725669565}
# Losses {'ner': 5075.648282811531}
# Losses {'ner': 5123.132918513516}
# Losses {'ner': 5191.926742146287}
# Losses {'ner': 5462.23516486821}
# Losses {'ner': 5531.002461549914}
# Losses {'ner': 5708.662144712261}
# Losses {'ner': 5987.456598899415}
# Losses {'ner': 6244.057456428273}
# Losses {'ner': 6345.196058188915}
# Losses {'ner': 6446.498759563431}
# Losses {'ner': 155.39081955351867}
# Losses {'ner': 278.1992207367439}
# Losses {'ner': 401.24313573406107}
# Losses {'ner': 567.3516764357992}
# Losses {'ner': 669.736952755462}
# Losses {'ner': 750.5087388864267}
# Losses {'ner': 856.1766094555496}
# Losses {'ner': 948.0330493436995}
# Losses {'ner': 1102.61744059607}
# Losses {'ner': 1253.403169942867}
# Losses {'ner': 1425.3301516564898}
# Losses {'ner': 1538.8998146920421}
# Losses {'ner': 1728.4778698336377}
# Losses {'ner': 1809.048125477675}
# Losses {'ner': 1958.3844876756702}
# Losses {'ner': 2050.606526413634}
# Losses {'ner': 2154.0423528297615}
# Losses {'ner': 2806.295460139103}
# Losses {'ner': 2958.915362484222}
# Losses {'ner': 3189.61624662525}
# Losses {'ner': 3278.4585615251854}
# Losses {'ner': 3464.8457857821777}
# Losses {'ner': 3766.441607349014}
# Losses {'ner': 4248.388890545437}
# Losses {'ner': 4479.11268123574}
# Losses {'ner': 4667.028309804591}
# Losses {'ner': 4890.607726956921}
# Losses {'ner': 5118.059209409374}
# Losses {'ner': 5258.941691559128}
# Losses {'ner': 5580.583580381557}
# Losses {'ner': 5696.840240172431}
# Losses {'ner': 5779.691532875964}
# Losses {'ner': 5975.246335934469}
# Losses {'ner': 6279.941761325666}
# Losses {'ner': 6331.389461702212}
# Losses {'ner': 6365.719858169893}
# Losses {'ner': 6579.1942382570005}
# Losses {'ner': 7136.341553699563}
# Losses {'ner': 7255.487455047251}
# Losses {'ner': 7321.747365367765}
# Losses {'ner': 151.91690962016582}
# Losses {'ner': 271.38403157517314}
# Losses {'ner': 390.4031369294971}
# Losses {'ner': 592.0560318510979}
# Losses {'ner': 661.8802946757901}
# Losses {'ner': 747.689299084103}
# Losses {'ner': 890.7303555606364}
# Losses {'ner': 998.1323274373741}
# Losses {'ner': 1266.7070411964983}
# Losses {'ner': 1363.8272674178756}
# Losses {'ner': 1476.6762982523237}
# Losses {'ner': 1561.09799598755}
# Losses {'ner': 1635.245571588785}
# Losses {'ner': 1687.814226627503}
# Losses {'ner': 1862.2793916696432}
# Losses {'ner': 1970.5582023048523}
# Losses {'ner': 2115.907977840838}
# Losses {'ner': 2286.9726718393836}
# Losses {'ner': 2371.265568130159}
# Losses {'ner': 2421.497872526233}
# Losses {'ner': 2559.1693047506847}
# Losses {'ner': 2670.1169935515204}
# Losses {'ner': 2846.415812996594}
# Losses {'ner': 3187.5844522346883}
# Losses {'ner': 3230.4009433526667}
# Losses {'ner': 3328.2761795221018}
# Losses {'ner': 3642.4460792716714}
# Losses {'ner': 3732.1060669907024}
# Losses {'ner': 3896.2979197597892}
# Losses {'ner': 4080.1892833536554}
# Losses {'ner': 4257.650571522681}
# Losses {'ner': 4361.320455968758}
# Losses {'ner': 4492.3929249797075}
# Losses {'ner': 4691.338982261252}
# Losses {'ner': 5032.737204208504}
# Losses {'ner': 5153.4757522214495}
# Losses {'ner': 5239.060619113909}
# Losses {'ner': 5323.894195639703}
# Losses {'ner': 5417.423133989156}
# Losses {'ner': 5564.3426456239295}
# Losses {'ner': 146.503490986448}
# Losses {'ner': 340.46226290034974}
# Losses {'ner': 693.2326053720681}
# Losses {'ner': 831.9865754922866}
# Losses {'ner': 997.7951346208356}
# Losses {'ner': 1278.3188535739682}
# Losses {'ner': 1350.3163118436714}
# Losses {'ner': 1471.9631728511085}
# Losses {'ner': 1559.3772724324153}
# Losses {'ner': 1620.3469271181189}
# Losses {'ner': 1768.4912359235846}
# Losses {'ner': 1984.4443359063976}
# Losses {'ner': 2055.0806476067905}
# Losses {'ner': 2222.8252437197757}
# Losses {'ner': 2377.0347368581374}
# Losses {'ner': 2474.8792947290153}
# Losses {'ner': 2557.39482023533}
# Losses {'ner': 2668.990631824376}
# Losses {'ner': 2741.8451365471196}
# Losses {'ner': 3027.4207687467647}
# Losses {'ner': 3116.271429019173}
# Losses {'ner': 3309.4657602213633}
# Losses {'ner': 3525.7827495968745}
# Losses {'ner': 3781.6248483234162}
# Losses {'ner': 3859.3087827368804}
# Losses {'ner': 4438.810741703135}
# Losses {'ner': 4566.087641737533}
# Losses {'ner': 4694.600892919807}
# Losses {'ner': 4863.3097725880725}
# Losses {'ner': 4967.86814894819}
# Losses {'ner': 5037.673433652271}
# Losses {'ner': 5305.569931974758}
# Losses {'ner': 5387.16121364131}
# Losses {'ner': 5504.099820447409}
# Losses {'ner': 5614.526559648359}
# Losses {'ner': 5661.162400369787}
# Losses {'ner': 5701.088818718241}
# Losses {'ner': 5750.88979732434}
# Losses {'ner': 5820.369032941202}
# Losses {'ner': 5934.152685339937}
# Losses {'ner': 352.1045674085617}
# Losses {'ner': 573.0995791688329}
# Losses {'ner': 636.178585689835}
# Losses {'ner': 822.40861059897}
# Losses {'ner': 906.7609511239862}
# Losses {'ner': 1125.3157519491797}
# Losses {'ner': 1332.1275675686484}
# Losses {'ner': 1425.464747936714}
# Losses {'ner': 1514.105921782293}
# Losses {'ner': 1598.562358944435}
# Losses {'ner': 1735.2157736756599}
# Losses {'ner': 1879.6731774248874}
# Losses {'ner': 1998.7220920478685}
# Losses {'ner': 2276.529192375554}
# Losses {'ner': 2417.7817490823327}
# Losses {'ner': 2705.8241833186003}
# Losses {'ner': 2856.984265575553}
# Losses {'ner': 2968.138343833638}
# Losses {'ner': 3351.814131001727}
# Losses {'ner': 3406.299990207983}
# Losses {'ner': 3490.6311864029904}
# Losses {'ner': 3552.401042814852}
# Losses {'ner': 3585.3671224330405}
# Losses {'ner': 3659.4753717329127}
# Losses {'ner': 3798.219861226103}
# Losses {'ner': 3838.971437463251}
# Losses {'ner': 3945.8898450915635}
# Losses {'ner': 4211.395988184673}
# Losses {'ner': 4418.185770351154}
# Losses {'ner': 4511.585614418011}
# Losses {'ner': 4654.169481993489}
# Losses {'ner': 5020.219144970946}
# Losses {'ner': 5126.3437908622545}
# Losses {'ner': 5257.218283911887}
# Losses {'ner': 5416.952131740585}
# Losses {'ner': 5556.0109442482335}
# Losses {'ner': 5619.668365995296}
# Losses {'ner': 5748.44270427049}
# Losses {'ner': 5903.799378927111}
# Losses {'ner': 5961.164906550936}
# Losses {'ner': 157.7422658908181}
# Losses {'ner': 355.1705779256299}
# Losses {'ner': 429.2949208084028}
# Losses {'ner': 582.1462998345087}
# Losses {'ner': 705.8188500284741}
# Losses {'ner': 1046.2830700158665}
# Losses {'ner': 1095.1570469589933}
# Losses {'ner': 1162.1078174824179}
# Losses {'ner': 1241.9482618747752}
# Losses {'ner': 1359.4272756157916}
# Losses {'ner': 1450.4074749191532}
# Losses {'ner': 1556.9747413014302}
# Losses {'ner': 1694.996287411941}
# Losses {'ner': 1822.6860296877421}
# Losses {'ner': 1959.6733320804633}
# Losses {'ner': 2671.7396572681464}
# Losses {'ner': 2818.047141859526}
# Losses {'ner': 2913.5717124435323}
# Losses {'ner': 2985.841717507431}
# Losses {'ner': 3058.2522560338975}
# Losses {'ner': 3157.218884901041}
# Losses {'ner': 3212.353877716727}
# Losses {'ner': 3484.2701512882777}
# Losses {'ner': 3530.8881515128596}
# Losses {'ner': 3810.3561671240313}
# Losses {'ner': 4073.935376439971}
# Losses {'ner': 4139.876065052551}
# Losses {'ner': 4193.082235615817}
# Losses {'ner': 4276.10307185314}
# Losses {'ner': 4344.128743880283}
# Losses {'ner': 4408.237904325448}
# Losses {'ner': 4482.018791173905}
# Losses {'ner': 4532.5825706448995}
# Losses {'ner': 4628.370252067212}
# Losses {'ner': 4668.989975798243}
# Losses {'ner': 4755.157387369673}
# Losses {'ner': 4849.948648893635}
# Losses {'ner': 4946.391994124174}
# Losses {'ner': 5447.835703842237}
# Losses {'ner': 6065.543357603147}
# Losses {'ner': 158.80264676059596}
# Losses {'ner': 271.24100944702514}
# Losses {'ner': 355.35195015429053}
# Losses {'ner': 493.7207546259451}
# Losses {'ner': 712.0426622399864}
# Losses {'ner': 787.488743298276}
# Losses {'ner': 817.6237840579497}
# Losses {'ner': 894.4710232183379}
# Losses {'ner': 1035.5968369521242}
# Losses {'ner': 1314.094209893995}
# Losses {'ner': 1380.4829009439954}
# Losses {'ner': 1444.8030499475235}
# Losses {'ner': 1645.7111584167824}
# Losses {'ner': 1682.3116871558877}
# Losses {'ner': 1803.6097681095407}
# Losses {'ner': 1852.894066872671}
# Losses {'ner': 1926.2181574880078}
# Losses {'ner': 2012.3578312034651}
# Losses {'ner': 2105.669569381599}
# Losses {'ner': 2431.6923714282157}
# Losses {'ner': 2531.133362302294}
# Losses {'ner': 2650.1130813841874}
# Losses {'ner': 2713.4195757010575}
# Losses {'ner': 3018.1545760729905}
# Losses {'ner': 3332.4327059598263}
# Losses {'ner': 3374.713080671904}
# Losses {'ner': 3428.5705770158647}
# Losses {'ner': 3466.910518620859}
# Losses {'ner': 3624.9953713739496}
# Losses {'ner': 3780.36580912559}
# Losses {'ner': 3835.8155420134}
# Losses {'ner': 3857.355737484641}
# Losses {'ner': 4249.97843111411}
# Losses {'ner': 4289.316921225587}
# Losses {'ner': 4531.817428833643}
# Losses {'ner': 4591.524461835394}
# Losses {'ner': 4823.776236904556}
# Losses {'ner': 4880.5224494847025}
# Losses {'ner': 4976.987333349589}
# Losses {'ner': 5228.670572283383}
# Losses {'ner': 641.0244658347219}
# Losses {'ner': 693.9829574276519}
# Losses {'ner': 895.9602652132598}
# Losses {'ner': 976.9774798886938}
# Losses {'ner': 1163.284843890564}
# Losses {'ner': 1204.6734776300354}
# Losses {'ner': 1294.1020506155537}
# Losses {'ner': 1371.030000362508}
# Losses {'ner': 1607.6008528805896}
# Losses {'ner': 1635.3504125317495}
# Losses {'ner': 1715.175953370047}
# Losses {'ner': 1791.638570723816}
# Losses {'ner': 1959.403294732555}
# Losses {'ner': 2050.6358161218786}
# Losses {'ner': 2119.1522412597233}
# Losses {'ner': 2246.264542613554}
# Losses {'ner': 2387.853192704174}
# Losses {'ner': 2587.7937299754967}
# Losses {'ner': 2657.515866791856}
# Losses {'ner': 2706.8808293183165}
# Losses {'ner': 2950.0702817155243}
# Losses {'ner': 3101.4691531820417}
# Losses {'ner': 3195.3109714868997}
# Losses {'ner': 3332.237130429764}
# Losses {'ner': 3389.7974473282793}
# Losses {'ner': 3532.7237802788713}
# Losses {'ner': 3613.391011564816}
# Losses {'ner': 3652.494217697129}
# Losses {'ner': 3710.5384192638503}
# Losses {'ner': 3791.5099024200517}
# Losses {'ner': 4128.8278049907}
# Losses {'ner': 4217.209910813346}
# Losses {'ner': 4440.124876648037}
# Losses {'ner': 4626.460664691718}
# Losses {'ner': 4706.502547028171}
# Losses {'ner': 4855.985949357202}
# Losses {'ner': 4925.887473178287}
# Losses {'ner': 5012.515020479086}
# Losses {'ner': 5061.598610759114}
# Losses {'ner': 5153.42896074819}

# %%
nlp.to_disk("tuned_spacy_ner_rus")

# %%
nlp_updated = spacy.load("tuned_spacy_ner_rus")
doc = nlp_updated(train_data[0][0])
print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
# Out:
# Entities [('Дарья Егоровна Ротманова', 'NAME'), ('daleth2002@yandex.ru', 'EMAIL'), ('+7(962)7738286', 'MOBILE'), ('40 лет', 'AGE'), ('высшее образование', 'EDUCATION'), ('Москва', 'CITY'), ('Менеджер интернет-магазина, товаровед, менеджер по продажам, оператор ПК, продавец-консультант, кассир', 'VACANCY'), ('Не готова к\xa0командировкам', 'WORKCONDITIONS'), ('По договорённости', 'SALARY'), ('13 лет\xa0и\xa06 месяцев', 'WOEXP'), ('Сентябрь\xa02017', 'WORKFROM'), ('май\xa02018', 'WORKTO'), ('Кладовщик, оператор склада', 'POSITION'), ('ООО "Бронницкий Ювелир", Москва', 'ORG'), ('Работа в 1С, 1С8,', 'SUMMARY'), ('CRM', 'SKILL'), ('Январь\xa02012', 'WORKFROM'), ('май\xa02015', 'WORKTO'), ('Менеджер онлайн-продаж', 'POSITION'), ('ОАО «МЮЗ» (Московский ювелирный завод), Москва', 'ORG'), ('Обработка и ведение интернет-заказов, приём звонков, консультации, работа с клиентами по телефону, взаимодействие с курьерскими службами, работа на складе интернет-магазина, взаимодействие с розничными магазинами, осуществление перемещения и отслеживание товара по интернет-заказам.', 'SUMMARY'), ('Июль\xa02011', 'WORKFROM'), ('январь\xa02012', 'WORKTO'), ('Продавец-консультант', 'POSITION'), ('Группа компаний "Регион-Ювелир", Москва', 'ORG'), ('Работа с покупателями, презентация изделий; приём, выкладка, постановка на учёт, обирковка изделий; работа с кассой, кассовой документацией, проведение инвентаризаций.', 'SUMMARY'), ('Апрель\xa02010', 'WORKFROM'), ('январь\xa02011', 'WORKTO'), ('Продавец-консультант', 'POSITION'), ('Декор-М, Производство и продажа ювелирных украшений, Москва', 'POSITION'), ('Консультации клиентов, выкладка и обирковка товара, постановка товара на приход, работа с кассой, кассовой документацией, участие в выставках, проведение инвентаризации.', 'SUMMARY'), ('Февраль\xa02008', 'WORKFROM'), ('январь\xa02010', 'WORKTO'), ('Менеджер интернет-магазина и продавец-консультант в шоуруме', 'POSITION'), ('Дом модных украшений и аксессуаров "Золотой Дельфин", (Производство и продажа ювелирных украшений), Москва', 'ORG'), ('Прием и обработка интернет-заказов и заказов по телефону, оформление доставки, внесение данных клиентов в базу данных, отслеживание изделий на стадиях производства, консультации покупателей по телефону; работа в шоуруме – поддержание порядка и чистоты витрин, консультация и обслуживание клиентов, работа с кассой, терминалом, упаковка покупок.', 'SUMMARY'), ('Август\xa02005', 'WORKFROM'), ('март\xa02007', 'WORKTO'), ('Менеджер по оптовым продажам', 'POSITION'), ('ИП "Любимые мелочи" (оптовая и розничная продажа бижутерии различных производителей, серебра, аксессуаров для волос, изделий из натуральных камней), Москва', 'ORG'), ('Прием товара, внесение новых поступлений в компьютер, оформление торгового зала (витрин)\r\nКонсультации покупателей, прием факсов.', 'SUMMARY'), ('Март\xa02004', 'WORKFROM'), ('март\xa02005', 'WORKTO'), ('Менеджер по оптовым продажам, оператор (опт)', 'POSITION'), ('ЗАО "Эталон-Женави" (производство и продажа ювелирной бижутерии), Москва', 'ORG'), ('Работа с оптовыми клиентами, составление и работа с накладными, оформление договоров, документов к оплате, составление ежедневных отчетов, проведение оплаты.', 'SUMMARY'), ('Июнь\xa01999', 'WORKFROM'), ('август\xa02002', 'WORKTO'), ('Продавец-консультант', 'POSITION'), ('Торговый центр "Тульско-Даниловский", Москва', 'ORG'), ('Продажа парфюмерии, косметики, бытовой химии, нижнего белья, украшений, сувениров, одежды, кожгалантереи, маникюрных принадлежностей, верхней одежды\r\n\r\nКонсультация и обслуживание покупателей, прием и выкладка товара, маркировка товара, работа с кассой, ведение кассового журнала, проведение учета', 'SUMMARY'), ('Высшее образование', 'EDUCATION'), ('2003', 'YEAROFGRAD'), ('Московский Городской Педагогический университет, г.', 'INTER'), ('Преподаватель немецкого языка', 'SPEC'), ('Высшее образование', 'EDUCATION'), ('2003', 'YEAROFGRAD'), ('Московский городской педагогический университет, г.', 'INTER'), ('Учитель русского язы ...

# %%
doco = docx.Document("D:\\Python\\Diplom\\К.docx")
text = ""
all_paras = doco.paragraphs
for para in all_paras:
    text += str(para.text)
tx = " ".join(text.split("\n"))

# %%
doc = nlp_updated(tx)
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Артур Валериевич Гаврюшев
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# . Контакты:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     culch1945@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EMAIL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +7(986)1177845Соискатель
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOBILE</span>
# </mark>
#  скрыл дату рождения,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     высшее образование
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EDUCATION</span>
# </mark>
# , cостоит в браке, есть детиРостов-на-Дону,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     готов к переезду: Москва, Санкт-ПетербургГражданство: РоссияТехнический писательПолная занятость, удаленная работа, готов к командировкамПо договорённостиОпыт работы 41 год и 8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKCONDITIONS</span>
# </mark>
#  месяцевМай 2021 –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ноябрь 20217
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
#  месяцевТехнический писатель (удаленно)ООО &quot;Квант&quot;, ЗеленоградРазработка технологического оборудования для производства микрочипов.Обязанности:Оформление пояснительных записок: технического предложения, эскизного проекта, технического проекта разрабатываемого комплекса технологического оборудования для производства микрочипов. Выполнение расчетов планируемых показателей надежности компонентов комплекса.Достижения:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Пояснительные записки, оформленные в соответствии с ГОСТ 2.105-2019 приняты заказчиком без замечаний.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SPEC</span>
# </mark>
#  Приобрел опыт создания шаблонов в Microsoft Word.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ноябрь 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKFROM</span>
# </mark>
#  –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     январь 20215
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
#  лет и 3 месяцаВедущий инженер-метролог / технический писательАО &quot;НПЦ &quot;Мера&quot;, МытищиРазработка и производство измерительных систем для стендовых испытаний двигателей для авиационной и ракетной техники и других изделий военного и гражданского назначений.Обязанности:- Разработка технической документации: ТУ, РЭ, ТЗ, описаний типа, методик поверки, программ испытаний с целью утверждения типа, протоколов испытаний, актов испытаний и д-р на автоматизированные информационно-измерительные системы стендов испытания авиационных, ракетных двигателей и других объектов, разработанных в том числе и по: ГОСТ 2., ГОСТ РВ, КТ-160D, ОСТ 1., РК-11;- проведение метрологической экспертизы технических заданий на разработку;- организация испытаний на ВВФ и калибровки первичных преобразователей, написание программ и методик испытаний.- участие в переговорах с заказчиками с целью уточнения требований к системе измерений;- участие в испытаниях систем с целью присвоения типа средств измерения.Примеры работ на сайте Росстандарта  под номерами: 66375-16, 66432-17, 67371-17, 70281-18, 71139-18, 73004-18, 74251-19, 76889-19, 77013-19, 78335-20, 78520-20, 79465-20. Вся разработанная документация прошла проверку в отделе экспертиз ВНИИМС, в Росстандарте и Военной Приемке без возвратов на доработку. Вся разработанная документация прошла проверку в отделе экспертиз ВНИИМС, в Росстандарте и Военной Приемке без возвратов на доработку.Достижения:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Вся разработанная документация прошла проверку в отделе экспертиз ВНИИМСа, в Росстандарте и Военной Приемке без возвратов на доработку.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SPEC</span>
# </mark>
#  Приобрел опыт работы в программе Microsoft Visio.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Апрель 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKFROM</span>
# </mark>
#  –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     сентябрь 20156
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
#  месяцевТехнический писательЗАО Научно-Исследовательский Центр &quot;ТЕХНОПРОГРЕСС&quot;, МоскваИспытательная лабораторияОбязанности:- оформление протоколов испытаний, проводимых лабораторией;- создание автоматизированной системы заполнения протоколов.Достижения:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Приобрел опыт создания базы данных в программе FileMaker, создания автоматизированной системы заполнения протоколов с использованием Microsoft Word
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SPEC</span>
# </mark>
# .
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ноябрь 2008
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKFROM</span>
# </mark>
#  –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     сентябрь 20123
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
#  года и 11 месяцевТехнический директорООО &quot;Дижитал Иновэйшинс&quot;, Ростов-на-ДонуОбязанности:- управление инфраструктурой, производственной средой и производством компании, занимающейся производством радиоэлектронной аппаратуры;- планирование и контроль технической политики компании;- разработка и внедрение регламентирующих документов (стандарты, должностные инструкции, карты процессов и т. д.);- управл

# %%
doc
# Out:
# Дарья Егоровна Ротманова. Контакты: daleth2002@yandex.ru, +7(962)7738286
# 40 лет (родилась 18 апреля 1981), высшее образование, не состоит в браке, детей нет
# Москва
# Гражданство: Россия
# Менеджер интернет-магазина, товаровед, менеджер по продажам, оператор ПК, продавец-консультант, кассир
# Не готова к командировкам
# По договорённости
# Опыт работы 13 лет и 6 месяцев
# Сентябрь 2017 – май 2018
# 9 месяцев
# Кладовщик, оператор склада
# ООО "Бронницкий Ювелир", Москва
# http://www.bronnitsy.com
# Обязанности:
# Работа в 1С, 1С8, CRM, приём товара, проведение его в 1С. Снятие изделий со склада-запаса, распределение и оформление для отправки в салоны, на дом, Спецсвязь, в сборку. Проверка изделий на брак. Оформление документации, упаковка и биркование изделий. Отправка изделий с курьерами, водителями, взаимодействие с менеджерами интернет-магазина.
# Январь 2012 – май 2015
# 3 года и 5 месяцев
# Менеджер онлайн-продаж
# ОАО «МЮЗ» (Московский ювелирный завод), Москва
# Обязанности:
# Обработка и ведение интернет-заказов, приём звонков, консультации, работа с клиентами по телефону, взаимодействие с курьерскими службами, работа на складе интернет-магазина, взаимодействие с розничными магазинами, осуществление перемещения и отслеживание товара по интернет-заказам.
# Июль 2011 – январь 2012
# 7 месяцев
# Продавец-консультант
# Группа компаний "Регион-Ювелир", Москва
# Обязанности:
# Работа с покупателями, презентация изделий; приём, выкладка, постановка на учёт, обирковка изделий; работа с кассой, кассовой документацией, проведение инвентаризаций.
# Апрель 2010 – январь 2011
# 10 месяцев
# Продавец-консультант
# Декор-М, Производство и продажа ювелирных украшений, Москва
# Обязанности:
# Консультации клиентов, выкладка и обирковка товара, постановка товара на приход, работа с кассой, кассовой документацией, участие в выставках, проведение инвентаризации.
# Февраль 2008 – январь 2010
# 2 года
# Менеджер интернет-магазина и продавец-консультант в шоуруме
# Дом модных украшений и аксессуаров "Золотой Дельфин", (Производство и продажа ювелирных украшений), Москва
# Обязанности:
# Прием и обработка интернет-заказов и заказов по телефону, оформление доставки, внесение данных клиентов в базу данных, отслеживание изделий на стадиях производства, консультации покупателей по телефону; работа в шоуруме – поддержание порядка и чистоты витрин, консультация и обслуживание клиентов, работа с кассой, терминалом, упаковка покупок. Размещение готовой продукции на складе, выкладка товара на витрины.
# Август 2005 – март 2007
# 1 год и 8 месяцев
# Менеджер по оптовым продажам
# ИП "Любимые мелочи" (оптовая и розничная продажа бижутерии различных производителей, серебра, аксессуаров для волос, изделий из натуральных камней), Москва
# Обязанности:
# Прием товара, внесение новых поступлений в компьютер, оформление торгового зала (витрин)
# Консультации покупателей, прием факсов.
# Работа с ПК, оформление договоров, введение поступающего товара в компьютер, составление ежедневного отчета.
# Составление заказов заводам-изготовителям, работа с поставщиками
# Прием и маркировка товара, оформление торгового зала.
# Работа с заказами по Интернету.
# Ведение кассового журнала, проведение учета, проведение оплаты, оформление торговой документации
# Март 2004 – март 2005
# 1 год и 1 месяц
# Менеджер по оптовым продажам, оператор (опт)
# ЗАО "Эталон-Женави" (производство и продажа ювелирной бижутерии), Москва
# Обязанности:
# Работа с оптовыми клиентами, составление и работа с накладными, оформление договоров, документов к оплате, составление ежедневных отчетов, проведение оплаты.
# Работа в шоуруме, оформление витрин, консультация клиентов, подборка изделий.
# Работа с кассой, ведение кассового журнала.
# Работа на складе: приём товара, распределение товара на складе, сбор заказов, проведение ежемесячного учета.
# Работа с заявками по факсу, почте, консультации по телефону.
# Июнь 1999 – август 2002
# 3 года и 3 месяца
# Продавец-консультант
# Торговый центр "Тульско-Даниловский", Москва
# Обязанности:
# Продажа парфюмерии, косметики, бытовой химии, нижнего белья, украшений, сувениров, одежды, кожгалантереи, маникюрных принадлежностей, верхней одежды
#
# Консультация и обслуживание покупателей, прием и выкладка товара, маркировка товара, работа с кассой, ведение кассового журнала, проведение учета
# Образование
# Высшее образование
# Вечерняя
# 2003
# Московский Городской Педагогический университет, г. Москва
# Факультет: Отделение дополнительного лингвистического образования
# Специальность: Преподаватель немецкого языка
# Высшее образование
# Дневная/Очная
# 2003
# Московский городской педагогический университет, г. Москва
# Факультет: Филологический
# Специальность: Учитель русского языка и литературы по специальности "Филология"
# Знания и навыки
# Профессиональные навыки:
# Взаимодействие с курьерскими службами, работа с первичной документацией, обслуживание покупателей, работа на кассe, ведение заказов, выполнение плана продаж, прием заказов, исходящие звонки, активные продажи, ведение деловой переписки, составление отчетности, ведение телефонных переговоров, ведение клиентской базы, работа с оргтехникой, уверенный пользователь ПК, оформление заказов, работа с поставщиками, заключениe договоров, техника продаж, ведение переговоров, прием входящих звонков, консультированиe клиентов, кассовый аппарат, интернeт, деловой этикет, продажи.
#
# Я коммуникабельная, энергичная, ответственная и обязательная.
# Креативная, внимательная, целеустремлённая.
# Отличная память, умение "схватывать на лету", быстрая реакция.
#
# Уверенный пользователь ПК, отличная грамотность.
# Знание 1С, 1С8.
# Хорошо разбираюсь в драгоценных, ювелирных, поделочных камнях, жемчуге, в драгоценных металлах, покрытиях, сплавах.
#
# Умею красиво, эффектно и целесообразно расположить товар, оформлять витрины.
# Умею работать с кассой и терминалом, знаю торговую документацию.
#
# Тренинги по товароведению и технике продаж – ОАО «МЮЗ» (2012, 2013 гг)
# Иностранные языки
# Английский язык — базовый
# Немецкий язык — cвободное владение

# %%
doc = nlp_updated(train_data[0][0])
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Дарья Егоровна Ротманова
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NAME</span>
# </mark>
# . Контакты:
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     daleth2002@yandex.ru
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EMAIL</span>
# </mark>
# ,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     +7(962)7738286
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MOBILE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40 лет
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">AGE</span>
# </mark>
#  (родилась 18 апреля 1981),
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     высшее образование
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EDUCATION</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Москва
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CITY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Менеджер интернет-магазина, товаровед, менеджер по продажам, оператор ПК, продавец-консультант, кассир
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">VACANCY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Не готова к командировкам
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKCONDITIONS</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     По договорённости
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SALARY</span>
# </mark>
# </br>Опыт работы
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13 лет и 6 месяцев
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WOEXP</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Сентябрь 2017
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKFROM</span>
# </mark>
#  –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     май 2018
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Кладовщик, оператор склада
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ООО &quot;Бронницкий Ювелир&quot;, Москва
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Работа в 1С, 1С8,
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SUMMARY</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CRM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SKILL</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Январь 2012
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKFROM</span>
# </mark>
#  –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     май 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Менеджер онлайн-продаж
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">POSITION</span>
# </mark>
# </br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ОАО «МЮЗ» (Московский ювелирный завод), Москва
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Обработка и ведение интернет-заказов, приём звонков, консультации, работа с клиентами по телефону, взаимодействие с курьерскими службами, работа на складе интернет-магазина, взаимодействие с розничными магазинами, осуществление перемещения и отслеживание товара по интернет-заказам.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SUMMARY</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Июль 2011
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKFROM</span>
# </mark>
#  –
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     январь 2012
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORKTO</span>
# </mark>
# </br>
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Продавец-консультант
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.

# %% [markdown]
# Таким образом, была обучена модель spaCy для задачи Named Entity Recognition для извлечения данных о соискателе на русском языке. Выжные данные имеют свои метки, например, Summary - метка, которая присваивается информации об обязанностях соискателя на одном из предыдущих мест работы, а метка EDUCATION присваивается информации об образовании соискателя. Далее эти данные записывались в MongoDB. В веб-приложении рекрутер мог сначала посмотреть главную информацию из резюме, например навыки кандидата, образование, увидеть контакты, и, если кандидат показался интересным, можно было посмотреть полное резюме. Данный способ позволяет сократить затраты времени на скрининг резюме, а также полученные данные можно в будущем использовать для создания системы, которая на основе ИИ будет сама отбирать наиболее релевантные вакансии резюме.
